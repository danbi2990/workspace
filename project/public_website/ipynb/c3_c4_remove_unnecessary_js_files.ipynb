# %%
from collections import Counter
import pandas as pd

from project.public_website.ipynb.jupyter_functions import remove_js_file_contain_keyword
from db.mongo import MyMongo

# %%
with MyMongo() as db:
    js_files = db.get_df_from_table('public_website', 'c3_js_files_per_domain')
# Out:
# <--Mongo Connected.
# Mongo Connection Closed.-->

# %%
len(js_files)
# Out:
# 1959

# %%
js_files_list = js_files['jsFile'].tolist(); len(js_files_list)
# Out:
# 1959

# %%
js_keyword_list = []
[js_keyword_list.extend(file.split('/')) for file in js_files_list]; len(js_keyword_list)
# Out:
# 8483

# %%
keyword_counter = Counter(js_keyword_list)

# %%
'''
jquery
prototype.js
'''

keyword_counter.most_common()
# Out:
# [('', 1890),
#  ('js', 1493),
#  ('common', 261),
#  ('jquery', 110),
#  ('lib', 99),
#  ('..', 84),
#  ('common.js', 83),
#  ('resources', 67),
#  ('csp', 63),
#  ('kor', 54),
#  ('comm', 53),
#  ('script', 47),
#  ('www', 43),
#  ('https:', 40),
#  ('ext', 40),
#  ('TouchEn', 38),
#  ('0404_mapmain', 38),
#  ('portal', 37),
#  ('cmm', 36),
#  ('2014', 34),
#  ('webapp', 31),
#  ('site', 30),
#  ('web', 29),
#  ('search', 26),
#  ('jquery-ui.min.js', 26),
#  ('jquery-ui.js', 25),
#  ('main.js', 25),
#  ('jscripts', 25),
#  ('html', 24),
#  ('http:', 24),
#  ('cmn', 23),
#  ('LSW', 22),
#  ('resource', 21),
#  ('egov_js2', 21),
#  ('pluginfree', 21),
#  ('ui', 21),
#  ('jquery.bxslider.min.js', 20),
#  ('co', 20),
#  ('egov_js', 19),
#  ('svc', 19),
#  ('share', 19),
#  ('HP', 19),
#  ('jquery.cookie.js', 17),
#  ('newMosf', 17),
#  ('cpis2gi', 17),
#  ('np2assets', 16),
#  ('layers', 16),
#  ('acrc', 16),
#  ('components', 16),
#  ('nxKey', 15),
#  ('main', 15),
#  ('styles', 15),
#  ('design', 15),
#  ('_js', 14),
#  ('2017', 14),
#  ('ei', 14),
#  ('minwon', 13),
#  ('jquery.easing.1.3.js', 13),
#  ('consumer', 13),
#  ('Web-home', 13),
#  ('nl', 13),
#  ('home', 13),
#  ('gov', 13),
#  ('koneps', 13),
#  ('fsc', 13),
#  ('_common', 12),
#  ('jquery-1.12.4.min.js', 12),
#  ('jquery.js', 12),
#  ('2017e', 12),
#  ('template', 12),
#  ('jquery-1.11.3.min.js', 11),
#  ('jquery.form.js', 11),
#  ('jsp', 11),
#  ('nfa', 11),
#  ('menu.js', 11),
#  ('react', 11),
#  ('2018', 11),
#  ('theme', 11),
#  ('museum_kr', 11),
#  ('nwel', 11),
#  ('korea', 11),
#  ('unikorea', 11),
#  ('kcs4g', 11),
#  ('jquery.bxslider.js', 10),
#  ('slick.min.js', 10),
#  ('bai', 10),
#  ('cms', 10),
#  ('raonsecure', 10),
#  ('plugin', 10),
#  ('dwr', 10),
#  ('jsLogin', 10),
#  ('cpin', 10),
#  ('include', 9),
#  ('jquery.min.js', 9),
#  ('jquery-1.11.1.min.js', 9),
#  ('wcom', 9),
#  ('openworks', 9),
#  ('spi', 9),
#  ('signgate', 9),
#  ('sg_scripts', 9),
#  ('mbshome', 9),
#  ('mbs', 9),
#  ('mnd', 9),
#  ('jquery-plugins', 9),
#  ('inc', 9),
#  ('nportal', 8),
#  ('AnySign4PC', 8),
#  ('gnb.js', 8),
#  ('popup.js', 8),
#  ('makePCookie.js', 8),
#  ('jquery-1.9.1.min.js', 8),
#  ('on', 8),
#  ('nppfs-1.9.0.js', 8),
#  ('jquery-1.11.0.min.js', 8),
#  ('search.js', 8),
#  ('json2.js', 8),
#  ('jquery-1.7.1.min.js', 8),
#  ('new', 8),
#  ('app', 8),
#  ('com', 8),
#  ('js_kor', 8),
#  ('pt', 8),
#  ('COOP', 8),
#  ('ocp', 8),
#  ('jquery-1.8.3.min.js', 7),
#  ('jquery-1.8.2.min.js', 7),
#  ('netfunnel.js', 7),
#  ('plugins', 7),
#  ('validation', 7),
#  ('user', 7),
#  ('wcs.naver.net', 7),
#  ('wcslog.js', 7),
#  ('jquery.blockUI.js', 7),
#  ('jquery.slides.min.js', 7),
#  ('sns.js', 7),
#  ('down.wetax.go.kr', 7),
#  ('script.js', 7),
#  ('util.js', 7),
#  ('wizvera', 7),
#  ('standard', 7),
#  ('eih', 7),
#  ('MOJ03', 7),
#  ('COM', 7),
#  ('nation', 7),
#  ('agentFree', 7),
#  ('MagicLine4Web', 7),
#  ('datatables', 7),
#  ('www.googletagmanager.com', 6),
#  ('gtag', 6),
#  ('anySign4PCInterface.js', 6),
#  ('lifeInfo', 6),
#  ('netfunnel', 6),
#  ('jquery.validate.js', 6),
#  ('jquery-migrate-1.2.1.js', 6),
#  ('_res', 6),
#  ('opm', 6),
#  ('jquery-1.9.1.js', 6),
#  ('ark', 6),
#  ('rui', 6),
#  ('postal', 6),
#  ('sub.js', 6),
#  ('comp', 6),
#  ('rs', 6),
#  ('kfs', 6),
#  ('smba', 6),
#  ('kiponet', 6),
#  ('renewal', 6),
#  ('scripts', 6),
#  ('intro', 6),
#  ('js_intro', 6),
#  ('ptrl', 6),
#  ('vols', 6),
#  ('01012', 6),
#  ('SecuKitNX', 6),
#  ('KICA', 6),
#  ('AnySign', 6),
#  ('rocket', 6),
#  ('static', 6),
#  ('CertMove', 6),
#  ('ab', 5),
#  ('gpkisecureweb', 5),
#  ('jquery.flexslider.js', 5),
#  ('scroll.js', 5),
#  ('owl.carousel.min.js', 5),
#  ('webfont.js', 5),
#  ('jquery.mousewheel.min.js', 5),
#  ('TouchEnNx.js', 5),
#  ('jquery-1.4.2.min.js', 5),
#  ('content.js', 5),
#  ('nxbiz', 5),
#  ('www.epost.go.kr', 5),
#  ('layout.js', 5),
#  ('slick.js', 5),
#  ('base64.js', 5),
#  ('www.epeople.go.kr', 5),
#  ('frame', 5),
#  ('jsFrameForOpener.js', 5),
#  ('egovframework', 5),
#  ('XecureObject', 5),
#  ('veraport', 5),
#  ('GPKIWeb', 5),
#  ('datepicker-rewrite', 5),
#  ('mobile', 5),
#  ('sliderkit', 5),
#  ('00016', 5),
#  ('MagicLine4', 5),
#  ('wus', 5),
#  ('myc', 5),
#  ('layout', 5),
#  ('yessignCert', 5),
#  ('client', 4),
#  ('ui.js', 4),
#  ('akc.js', 4),
#  ('jquery-autocomplete', 4),
#  ('captcha.js', 4),
#  ('jquery.mCustomScrollbar.concat.min.js', 4),
#  ('gpki_module_1.4', 4),
#  ('jquery-1.10.2.min.js', 4),
#  ('jquery.mCustomScrollbar.js', 4),
#  ('calendar', 4),
#  ('calendar.js', 4),
#  ('kcc2016', 4),
#  ('beta.fix.js', 4),
#  ('js.js', 4),
#  ('ark.js', 4),
#  ('slide', 4),
#  ('checkBrowser.js', 4),
#  ('logininfoURL.js', 4),
#  ('_UI', 4),
#  ('_lib', 4),
#  ('sesw.hometax.go.kr', 4),
#  ('secs', 4),
#  ('veraportNX', 4),
#  ('veraport20.js', 4),
#  ('veraport20_handler.js', 4),
#  ('board.js', 4),
#  ('jquery-latest.min.js', 4),
#  ('interface', 4),
#  ('default.js', 4),
#  ('bootstrap', 4),
#  ('gpkiweb', 4),
#  ('install', 4),
#  ('newkfsweb', 4),
#  ('ajax', 4),
#  ('xtractor_cookie.js', 4),
#  ('jquery.validate.min.js', 4),
#  ('modernizr-2.6.2.min.js', 4),
#  ('prtl', 4),
#  ('form', 4),
#  ('logic', 4),
#  ('D2B_OUT', 4),
#  ('jquery-ui-1.10.3.custom', 4),
#  ('naaccweb', 4),
#  ('ca', 4),
#  ('jquery-1.7.2.js', 4),
#  ('spo', 4),
#  ('t1.daumcdn.net', 4),
#  ('center', 4),
#  ('Xecure', 4),
#  ('jslibrary', 4),
#  ('caisBMHS', 4),
#  ('jquery-1.6.4.min.js', 4),
#  ('modernizr.custom.js', 3),
#  ('navigation.js', 3),
#  ('html5shiv.js', 3),
#  ('minwon_isp', 3),
#  ('minwon_common.js', 3),
#  ('prototype.js', 3),
#  ('comm.js', 3),
#  ('jquery-1.10.2.js', 3),
#  ('jquery.bxslider', 3),
#  ('jquery.easing.1.3.min.js', 3),
#  ('user.js', 3),
#  ('cms.js', 3),
#  ('date.format.js', 3),
#  ('jquery.number.min.js', 3),
#  ('jquery.PrintArea.js_4.js', 3),
#  ('statistics.js', 3),
#  ('popup', 3),
#  ('jquery.word-break-keep-all.min.js', 3),
#  ('picker.js', 3),
#  ('plugins.js', 3),
#  ('code.jquery.com', 3),
#  ('pc', 3),
#  ('hancom', 3),
#  ('JValidation.js', 3),
#  ('GPKIFunc.js', 3),
#  ('var.js', 3),
#  ('object.js', 3),
#  ('install.js', 3),
#  ('datepicker.js', 3),
#  ('miya_validator.js', 3),
#  ('acecounter', 3),
#  ('acecounter_V70.js', 3),
#  ('MemAutoLogout.js', 3),
#  ('navi_focus.js', 3),
#  ('service.epost.go.kr', 3),
#  ('dapa', 3),
#  ('common-scroll.js', 3),
#  ('jquery.form.min.js', 3),
#  ('logger.js', 3),
#  ('jquery.dotdotdot.min.js', 3),
#  ('external', 3),
#  ('jquery-1.4.4.min.js', 3),
#  ('quick.js', 3),
#  ('sites', 3),
#  ('mafra', 3),
#  ('rexpert', 3),
#  ('pp', 3),
#  ('veraport20_multi.js', 3),
#  ('install20', 3),
#  ('message', 3),
#  ('zoom.js', 3),
#  ('slides.min.jquery.js', 3),
#  ('vm', 3),
#  ('nppfs-1.6.0.js', 3),
#  ('login.js', 3),
#  ('www.google-analytics.com', 3),
#  ('analytics.js', 3),
#  ('engine.js', 3),
#  ('date-time', 3),
#  ('temp.js', 3),
#  ('kakao.min.js', 3),
#  ('openapi.map.naver.com', 3),
#  ('openapi', 3),
#  ('html5.js', 3),
#  ('sym', 3),
#  ('global.js', 3),
#  ('kminwon', 3),
#  ('newdesign', 3),
#  ('xecureweb.js', 3),
#  ('jquery.xdomainajax.js', 3),
#  ('dist', 3),
#  ('install_internal.js', 3),
#  ('map_js_init', 3),
#  ('jquery.cycle.all.js', 3),
#  ('kor_ip', 3),
#  ('12', 3),
#  ('1', 3),
#  ('tts.js', 3),
#  ('jquery-min.js', 3),
#  ('fsw.js', 3),
#  ('scrap.js', 3),
#  ('i18n', 3),
#  ('jquery-1.10.1.min.js', 3),
#  ('as', 3),
#  ('_custom', 3),
#  ('jqgrid', 3),
#  ('trifadmndclr', 3),
#  ('cscl', 3),
#  ('hisimpan.mohw.go.kr', 3),
#  ('sp2', 3),
#  ('web2', 3),
#  ('classie.js', 2),
#  ('jquery.appear.js', 2),
#  ('crevit_setup', 2),
#  ('crevit', 2),
#  ('deploy', 2),
#  ('magicline4np', 2),
#  ('uploadify', 2),
#  ('jquery-1.11.3.js', 2),
#  ('common_topmenu.js', 2),
#  ('bpr_isp', 2),
#  ('new_g4c_common.js', 2),
#  ('ControlUtils.js', 2),
#  ('commonGise.js', 2),
#  ('share.js', 2),
#  ('leecomValidation.js', 2),
#  ('typecheck.js', 2),
#  ('obcheck.js', 2),
#  ('leecomUtil.js?version=201605262100', 2),
#  ('gubiDoc.js', 2),
#  ('test_skin.js', 2),
#  ('platform.twitter.com', 2),
#  ('widgets.js', 2),
#  ('messages_ko.js', 2),
#  ('additional-methods.js', 2),
#  ('stringUtils.js', 2),
#  ('trimpath-template-1.0.38.js', 2),
#  ('jquery.autocomplete.min.js ', 2),
#  ('jquery-1.9.0.js', 2),
#  ('jquery-ui-multiselect', 2),
#  ('src', 2),
#  ('jquery.multiselect.js', 2),
#  ('validationUtils.js', 2),
#  ('custom-hrdp.js', 2),
#  ('jquery-asPieProgress.js', 2),
#  ('numberUtils.js', 2),
#  ('dateUtils.js', 2),
#  ('fileUtils.js', 2),
#  ('jquery.printElement.js', 2),
#  ('jquery-migrate-1.2.1.min.js', 2),
#  ('picker.date.js', 2),
#  ('banner', 2),
#  ('datepicker.min.js', 2),
#  ('visual', 2),
#  ('jquery.fullPage.min.js', 2),
#  ('select2.min.js', 2),
#  ('SecureProto.js', 2),
#  ('jquery.PrintArea.js', 2),
#  ('applex_wdigm', 2),
#  ('header.js', 2),
#  ('jquery.ui.datepicker-ko.js', 2),
#  ('date.js', 2),
#  ('JControl.js', 2),
#  ('AnySign4PC_min.js', 2),
#  ('jquery.slides.js', 2),
#  ('loader.js', 2),
#  ('hashlink_fix.js', 2),
#  ('cookie.js', 2),
#  ('jquery-3.2.1.min.js', 2),
#  ('flash_load.js', 2),
#  ('flash_conf.js', 2),
#  ('framework', 2),
#  ('TouchEnNx_exproto.js', 2),
#  ('TouchEnNxKey_Interface.js', 2),
#  ('TouchEnNxKey.js', 2),
#  ('jquery.customInput.js', 2),
#  ('jquery.ui.datepicker-ko.min.js', 2),
#  ('usr', 2),
#  ('masterSkin', 2),
#  ('modernizr.min.js', 2),
#  ('n_common.js', 2),
#  ('common_ajax.js', 2),
#  ('common_util.js', 2),
#  ('js.cookie.js', 2),
#  ('jquery.xml2json.js', 2),
#  ('newmain', 2),
#  ('TweenMax.min.js', 2),
#  ('bbs', 2),
#  ('highcharts', 2),
#  ('sliderkit.counter.1.0.pack.js', 2),
#  ('mCustomScrollbar.min.js', 2),
#  ('login', 2),
#  ('jquery-cookie.js', 2),
#  ('www.google.com', 2),
#  ('jsapi', 2),
#  ('popupzone.js', 2),
#  ('slide.js', 2),
#  ('satis.js', 2),
#  ('autocom.js', 2),
#  ('jquery-1.6.1.min.js', 2),
#  ('jquery.ui.datepicker.js', 2),
#  ('nav.js', 2),
#  ('masonry.pkgd.min.js', 2),
#  ('dqAutoCompleteCommon.js', 2),
#  ('jquery.rolling.js', 2),
#  ('oauth', 2),
#  ('oauth.js', 2),
#  ('sha1.js', 2),
#  ('v3', 2),
#  ('ls', 2),
#  ('slick', 2),
#  ('tab.js', 2),
#  ('idangerous.swiper.min.js', 2),
#  ('cm', 2),
#  ('zip', 2),
#  ('EgovZipPopup.js', 2),
#  ('topmenu.js', 2),
#  ('layout_new.js', 2),
#  ('jquery-ui-1.11.4.js', 2),
#  ('g4b.js;jsessionid=9lReZcqXh0XANOevgycjceYdeBTVveAtFCogLbSs1vlMdYAr0mV52u796brHzaDt.g4bap1_servlet_engine1',
#   2),
#  ('g4b.js;jsessionid=hugPWTaUACHpYpQrUW1qDWck9ntbjoRQFPqt14msVUacQ1s10B1dDjSAQOk1BKAW.g4bap1_servlet_engine1',
#   2),
#  ('CmmUtil.js;jsessionid=9lReZcqXh0XANOevgycjceYdeBTVveAtFCogLbSs1vlMdYAr0mV52u796brHzaDt.g4bap1_servlet_engine1',
#   2),
#  ('jquery-1.6.2.min.js', 2),
#  ('jquery-1.6.2.min.js;jsessionid=hugPWTaUACHpYpQrUW1qDWck9ntbjoRQFPqt14msVUacQ1s10B1dDjSAQOk1BKAW.g4bap1_servlet_engine1',
#   2),
#  ('g4b.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap1_servlet_engine1',
#   2),
#  ('jquery-1.6.2.min.js;jsessionid=9lReZcqXh0XANOevgycjceYdeBTVveAtFCogLbSs1vlMdYAr0mV52u796brHzaDt.g4bap1_servlet_engine1',
#   2),
#  ('jquery-1.6.2.min.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap1_servlet_engine1',
#   2),
#  ('CmmUtil.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap1_servlet_engine1',
#   2),
#  ('g4b.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap2_servlet_engine1',
#   2),
#  ('jquery-1.6.2.min.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap2_servlet_engine1',
#   2),
#  ('CmmUtil.js;jsessionid=hugPWTaUACHpYpQrUW1qDWck9ntbjoRQFPqt14msVUacQ1s10B1dDjSAQOk1BKAW.g4bap1_servlet_engine1',
#   2),
#  ('CmmUtil.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap2_servlet_engine1',
#   2),
#  ('webwidget_slideshow_dot.js', 2),
#  ('CmmUtil.js', 2),
#  ('saml.onepass.go.kr', 2),
#  ('onepass-client-1.0.0.js', 2),
#  ('rolling.js', 2),
#  ('jquery-ui-1.10.3.custom.min.js', 2),
#  ('lightslider.min.js', 2),
#  ('ck.softforum.co.kr', 2),
#  ('CKKeyPro', 2),
#  ('CKKeyPro.js', 2),
#  ('rollover.js', 2),
#  ('jquery-modal', 2),
#  ('tea', 2),
#  ('jquery.fullPage.js', 2),
#  ('moment.js', 2),
#  ('webPlugins', 2),
#  ('nlogin', 2),
#  ('wnsearch.js', 2),
#  ('plugin.js', 2),
#  ('install_config.js', 2),
#  ('jquery-1.12.4.js', 2),
#  ('mp', 2),
#  ('ajax.js', 2),
#  ('menu_model.js', 2),
#  ('jquery-ui-1.11.4.custom', 2),
#  ('jquery.message.js', 2),
#  ('swiper.min.js', 2),
#  ('apl', 2),
#  ('eqk_layer', 2),
#  ('eqk.js', 2),
#  ('common.js?ver=20171227', 2),
#  ('warninglayer.js', 2),
#  ('session.js', 2),
#  ('contents.js', 2),
#  ('fadeBanner.js', 2),
#  ('spi.maps.daum.net', 2),
#  ('imap', 2),
#  ('postcode.v2.js', 2),
#  ('jquery-ui-1.11.4', 2),
#  ('jquery.bpopup.min.js', 2),
#  ('hb_sub.js', 2),
#  ('global_common.js?v=1', 2),
#  ('common_address.js', 2),
#  ('jquery.easyResponsiveTabs.js', 2),
#  ('common_bbs.js', 2),
#  ('zipcode', 2),
#  ('bbs_zipcode.js', 2),
#  ('fusioncharts', 2),
#  ('join', 2),
#  ('frontUi.js', 2),
#  ('crossDomain.js', 2),
#  ('menu', 2),
#  ('index.js', 2),
#  ('inf', 2),
#  ('pdb', 2),
#  ('config', 2),
#  ('sbGrid', 2),
#  ('kr', 2),
#  ('softbowl', 2),
#  ('jquery.ui.core.js', 2),
#  ('rum.beusable.net', 2),
#  ('b170510e100133u636', 2),
#  ('custom.js', 2),
#  ('ca2012.js?v=1', 2),
#  ('common.js?v=1', 2),
#  ('jquery.alphanumeric.pack.js', 2),
#  ('addons', 2),
#  ('searchEngine', 2),
#  ('t1.kakaocdn.net', 2),
#  ('vendor', 2),
#  ('common_Key_Mouse.js', 2),
#  ('search530', 2),
#  ('xecureCommon.js', 2),
#  ('xecureweb_up.js', 2),
#  ('uicommon.js', 2),
#  ('cpcommon.js', 2),
#  ('rollingbanner_20120724.js', 2),
#  ('VeraCheck.js', 2),
#  ('flash.js', 2),
#  ('fncommon.js', 2),
#  ('is.js', 2),
#  ('easykeytec', 2),
#  ('tablesummary.js', 2),
#  ('jqcommon.js', 2),
#  ('jquery-1.12.2.min.js', 2),
#  ('dat', 2),
#  ('fusionCharts', 2),
#  ('spc', 2),
#  ('MagicLine4NP', 2),
#  ('comn', 2),
#  ('magicsso', 2),
#  ('jquery.paging.js', 2),
#  ('iframeheight.min.js', 2),
#  ('fsc.js', 2),
#  ('jquery-1.7.min.js', 2),
#  ('browser.js', 2),
#  ('jcarousellite_1.0.1.js', 2),
#  ('www.g2b.go.kr', 2),
#  ('parsley', 2),
#  ('jquery.fullPage.min.js?ver=2', 1),
#  ('jquery.mCustomScrollbar.js?ver=2', 1),
#  ('html5.js?ver=2', 1),
#  ('jquery.magnific-popup.min.js?ver=2', 1),
#  ('search_btn.js', 1),
#  ('js?id=UA-112403815-1', 1),
#  ('jquery.easings.min.js?ver=2', 1),
#  ('jquery.flexslider-min.js?ver=2', 1),
#  ('jquery-1.11.0.min.js?ver=2', 1),
#  ('127.0.0.1:49767', 1),
#  ('ntum', 1),
#  ('reqeust?callback=jQuery1900049410448425901365_1543367129120&scheme=eyJzb3VyY2UiOjAsImNtZCI6M30%3D&_=1543367129121',
#   1),
#  ('OID-20171110171838_env.js', 1),
#  ('AxDSMSecureAuth.js', 1),
#  ('security_main.js', 1),
#  ('magicline.js?v=20171114', 1),
#  ('security.js', 1),
#  ('ab080com.js', 1),
#  ('abcommon.js', 1),
#  ('abmessage.js', 1),
#  ('crevit.jquery.js', 1),
#  ('nppfs-2.0.0.js', 1),
#  ('ml_jquery.js', 1),
#  ('certLoin.js', 1),
#  ('jquery-ui-1.8.5.min.js', 1),
#  ('jquery.uploadify.v2.1.0.min.js', 1),
#  ('swfobject.js', 1),
#  ('police.js', 1),
#  ('i9ResoponseVoice2.js', 1),
#  ('iscroll.js', 1),
#  ('xjsv.js', 1),
#  ('AA090_eissue_apply_list.js?version=201706220000', 1),
#  ('.', 1),
#  ('leecomUtil.js', 1),
#  ('TouchEn.js?version=201706230000', 1),
#  ('kbdSecurity.js?version=201512102100', 1),
#  ('miwon_infoLife.js', 1),
#  ('mois_skin.js?v=181122', 1),
#  ('sns_direct.js', 1),
#  ('jbcy', 1),
#  ('base.js', 1),
#  ('objValueCheck.js', 1),
#  ('logAnalysis.js?version=1.1', 1),
#  ('jquery.carouFredSel-5.5.0-packed.js', 1),
#  ('syjy', 1),
#  ('icheck.js', 1),
#  ('jquery.selectBox.js', 1),
#  ('webponent.licenseKey.js', 1),
#  ('jquery.qtip.js', 1),
#  ('Printmade3.js', 1),
#  ('webponent.chart.js?ran=8867179', 1),
#  ('jquery-1.11.2.min.js', 1),
#  ('raphael.js?ran=6151469', 1),
#  ('Form.js', 1),
#  ('webponent.comm.common.js?ran=1009972', 1),
#  ('bxslider', 1),
#  ('Common.js', 1),
#  ('popControl.js', 1),
#  ('m_mn.js', 1),
#  ('jquery-ui-1.11.4.min.js', 1),
#  ('owl.js', 1),
#  ('visual.js', 1),
#  ('content_01.js', 1),
#  ('consumer_main.js', 1),
#  ('smartPop.js', 1),
#  ('content_02.js', 1),
#  ('canvas.js', 1),
#  ('banner_21.js', 1),
#  ('remodal.js', 1),
#  ('seed.user.app.js', 1),
#  ('consumer_sub.js', 1),
#  ('consumer_common.js', 1),
#  ('legacy.js', 1),
#  ('visual_80.js', 1),
#  ('popup_41.js', 1),
#  ('clamp.min.js', 1),
#  ('raonnx', 1),
#  ('comBannerAllim.js', 1),
#  ('sliding.js', 1),
#  ('clipboard.min.js.js', 1),
#  ('js?id=UA-117784262-1', 1),
#  ('jsSessionCheck.js', 1),
#  ('UseGpinJs.js', 1),
#  ('httpRequest.js', 1),
#  ('jsNumber.js', 1),
#  ('jsSessionTimeoutAlert.js', 1),
#  ('http_error_pop.js', 1),
#  ('anySign4PCInterface.js?version=1543368192558', 1),
#  ('nj.validator.js', 1),
#  ('UOnJoinCheck.js', 1),
#  ('UseGpinJs.js?version=1.7', 1),
#  ('html5shiv.min.js', 1),
#  ('component.js', 1),
#  ('fontSize_v1.1.js', 1),
#  ('jquery-ui-1.10.4.custom.min.js', 1),
#  ('applex_local.js?version=1.02', 1),
#  ('jsPnumber.js', 1),
#  ('nj.common.js', 1),
#  ('UserLogin.js', 1),
#  ('UOnIdPwSearch.js', 1),
#  ('PhoneNumCheck.js', 1),
#  ('js.js?version=1.1', 1),
#  ('jsMsg.js', 1),
#  ('mypage', 1),
#  ('cvreq', 1),
#  ('UPcMyCvreqTsView.js?version=1.03', 1),
#  ('UPcCvreqForm.js?version=1.70', 1),
#  ('lnb.js', 1),
#  ('footer.js', 1),
#  ('publishing.js', 1),
#  ('residentNoCheck.js', 1),
#  ('nppfs-1.9.0.js?dummy=20181128091342302', 1),
#  ('user_notice_pop.js', 1),
#  ('jquery.wheel.js', 1),
#  ('applex_local.js?version=1.01', 1),
#  ('jsValid.js', 1),
#  ('RealName.js', 1),
#  ('virtualkeyboard.js', 1),
#  ('banner_zone.js', 1),
#  ('www.eprivacy.or.kr:40018', 1),
#  ('seal', 1),
#  ('mark.js', 1),
#  ('jquery.cookies.js', 1),
#  ('jquery.carouFredSel.js', 1),
#  ('ssl.js', 1),
#  ('popupMng', 1),
#  ('script.do?siteId=2', 1),
#  ('jsRolling.js', 1),
#  ('pagenav.js', 1),
#  ('jquery-ui-timepicker-addon-0.5.min.js', 1),
#  ('c_common.js', 1),
#  ('init.js', 1),
#  ('mainSlider.js', 1),
#  ('searchedkwd.js', 1),
#  ('commLink.js', 1),
#  ('commUtil.js', 1),
#  ('jquery-countTo.js', 1),
#  ('r_common.js', 1),
#  ('nxbiz_handler_internal.min.js?0', 1),
#  ('nxbiz.js?0', 1),
#  ('nxbiz_internal.js?0', 1),
#  ('user_script.js', 1),
#  ('jsx.js', 1),
#  ('nxbiz_handler.js?0', 1),
#  ('nxbiz_config2.js?0', 1),
#  ('wetax_skin.js', 1),
#  ('lodash-3.10.1.min.js', 1),
#  ('jquery-flexisel.js', 1),
#  ('js?id=UA-113305868-1', 1),
#  ('jquery-menu.js', 1),
#  ('cmmn.js', 1),
#  ('jquery-touchSlider.js', 1),
#  ('cookies.js', 1),
#  ('siteoverlay2.js', 1),
#  ('notice_popup.js', 1),
#  ('main_popup.js', 1),
#  ('mvisual.js', 1),
#  ('tab_menu_main.js', 1),
#  ('json2xml.js', 1),
#  ('jquery-confirm.min.js', 1),
#  ('worknet.snsLogin.js', 1),
#  ('worknet.common.js', 1),
#  ('worknet.jobSchDptInfo.js', 1),
#  ('TouchEnNx_install.js', 1),
#  ('keis.window.js', 1),
#  ('worknet.empInfo.js', 1),
#  ('TouchEnNx_config.js', 1),
#  ('TouchEnNx_loader.js', 1),
#  ('worknet.search.js', 1),
#  ('keis.import.js', 1),
#  ('keis.import.min.js', 1),
#  ('TouchEnNx_daemon.js', 1),
#  ('jquery.jqtransform.js', 1),
#  ('dqAutoCompleteMain.js', 1),
#  ('sns', 1),
#  ('kakao.js', 1),
#  ('date-ko-KR.js', 1),
#  ('string.js', 1),
#  ('common_event.js', 1),
#  ('lang', 1),
#  ('message_set_ko.js', 1),
#  ('ui_onload.js', 1),
#  ('class.js', 1),
#  ('main_event.js', 1),
#  ('file_function.js', 1),
#  ('menu.js?version=20140825', 1),
#  ('log.kcisa.kr', 1),
#  ('tag', 1),
#  ('WebNibbler_mcst_go_kr.js', 1),
#  ('atm.acecounter.com', 1),
#  ('ac.js?tid=100567BU-10-A&hsn=www.mcst.go.kr&hrf=&dvp=0&tgp=&tn1=&tn2=0&tn3=0&tw1=&tw2=&tw3=&tw4=&tw5=&tw6=&tw7=&rnd=1543363961733&py=0',
#   1),
#  ('cr.acecounter.com', 1),
#  ('Web', 1),
#  ('AceCounter_AW.js?gc=BH2A39943863446&py=0&gd=gtb7&gp=8080&up=NaPm_Ncisy&rd=1543363961735',
#   1),
#  ('common_function.js', 1),
#  ('jquery-ui-1.11.0.js', 1),
#  ('simplemodal', 1),
#  ('jquery.simplemodal-1.4.4.js', 1),
#  ('js?id=UA-47293126-2', 1),
#  ('jquery.jshowoff.js', 1),
#  ('style', 1),
#  ('visitLog.js', 1),
#  ('fnct', 1),
#  ('site_user.js', 1),
#  ('_SITES', 1),
#  ('mafra_JW_MS_K2WT003_M', 1),
#  ('mafra_JW_MS_K2WT003_S', 1),
#  ('ui_searchedhist.js', 1),
#  ('rnic-search.js', 1),
#  ('ui_main.js', 1),
#  ('ui_search.js', 1),
#  ('ui_autocomplete.js', 1),
#  ('rnic-common.js', 1),
#  ('jquery.fakeform.min.js', 1),
#  ('placeholders.min.js', 1),
#  ('jquery.easing.min.js', 1),
#  ('constant.js', 1),
#  ('input_name.js', 1),
#  ('nonActiveX', 1),
#  ('inca', 1),
#  ('mall.js', 1),
#  ('externalJS', 1),
#  ('big', 1),
#  ('big.min.js', 1),
#  ('domain.js', 1),
#  ('common_te_util.js', 1),
#  ('javascriptPluginAll_NTS_6.js', 1),
#  ('common_biz.js', 1),
#  ('common_const.js', 1),
#  ('token.do?query=_DrS0DENDVDBDNdIR0RQ1', 1),
#  ('rexpert.print.service.js', 1),
#  ('127.0.0.1:16105', 1),
#  ('?callback=jQuery18307824027804931222_1543366038014&data=%7B%22cmd%22%3A%22getOsInfo%22%2C%22sid%22%3A%221543366038016%22%2C%22data%22%3A%7B%7D%7D&_=1543366038524',
#   1),
#  ('common_message.js', 1),
#  ('install_vp.js', 1),
#  ('common_pp.js', 1),
#  ('nts-report.js', 1),
#  ('common_log.js', 1),
#  ('netfunnel2.js', 1),
#  ('websquare', 1),
#  ('en.js', 1),
#  ('jquery.responsive.min.js', 1),
#  ('egovResource', 1),
#  ('commonThinkFairUser.js', 1),
#  ('luris.js', 1),
#  ('plan.js', 1),
#  ('modernizr.min.0.js', 1),
#  ('prefixfree.min.js', 1),
#  ('mainslide.js', 1),
#  ('fmk.js', 1),
#  ('km', 1),
#  ('estateInfo.js', 1),
#  ('mainPopup.js', 1),
#  ('nosquery-1.11.3.min.js', 1),
#  ('html2canvas', 1),
#  ('html2canvas.js', 1),
#  ('dapi.kakao.com', 1),
#  ('v2', 1),
#  ('maps', 1),
#  ('sdk.js?appkey=a49f35527824e965682a08eec17b030f', 1),
#  ('top.js', 1),
#  ('rsStatInfo.js', 1),
#  ('es6-promise.auto.js', 1),
#  ('commonUtil.js?ver=1.0', 1),
#  ('jquery.twbsPagination.js', 1),
#  ('imageViewer', 1),
#  ('imageviewer.js', 1),
#  ('highcharts-more.js', 1),
#  ('lotdetailinfo', 1),
#  ('lotdetailinfo.js', 1),
#  ('highcharts.js', 1),
#  ('jquery.sliderkit.1.9.2.js', 1),
#  ('jquery.cfSlider.js', 1),
#  ('jquery.tooltipster.js', 1),
#  ('playSound.js', 1),
#  ('tiny_mce', 1),
#  ('tiny_mce.js', 1),
#  ('url.min.js', 1),
#  ('tinyMceEditor.js', 1),
#  ('common_ui.js', 1),
#  ('mobile_responsive.js', 1),
#  ('datepicker_kr.js', 1),
#  ('view', 1),
#  ('bannerutil.js', 1),
#  ('jquery.jcarousel.min.js', 1),
#  ('jquery.fitvids.js', 1),
#  ('common_main.js', 1),
#  ('jquery.motionj.fadeBanner.js', 1),
#  ('board_validation.js', 1),
#  ('wz_tooltip.js', 1),
#  ('main_ui.js', 1),
#  ('post.js', 1),
#  ('jquery-ui-1.10.3.min.js', 1),
#  ('alio-1.0.0.js', 1),
#  ('select2-3.5.2', 1),
#  ('select2.js', 1),
#  ('0_0.js', 1),
#  ('La3_12_style.js', 1),
#  ('La3_12.js', 1),
#  ('5_5_style.js', 1),
#  ('link.js', 1),
#  ('La1_10.js', 1),
#  ('2_2_style.js', 1),
#  ('qgis2web_expressions.js', 1),
#  ('La5_14_style.js', 1),
#  ('1_1_style.js', 1),
#  ('1_1.js', 1),
#  ('La5_14.js', 1),
#  ('La4_13_style.js', 1),
#  ('layers.js?a=1', 1),
#  ('qgis2web.js', 1),
#  ('La0_9_style.js', 1),
#  ('Autolinker.min.js', 1),
#  ('La0_9.js?a=1', 1),
#  ('3_3.js', 1),
#  ('border_7_style.js', 1),
#  ('La4_13.js', 1),
#  ('6_6_style.js', 1),
#  ('La2_11_style.js', 1),
#  ('ol.js', 1),
#  ('5_5.js', 1),
#  ('3_3_style.js', 1),
#  ('4_4.js', 1),
#  ('border_7.js', 1),
#  ('0_0_style.js', 1),
#  ('6_6.js', 1),
#  ('4_4_style.js', 1),
#  ('La2_11.js', 1),
#  ('La1_10_style.js', 1),
#  ('world_dotB_8_style.js', 1),
#  ('world_dotB_8.js', 1),
#  ('polyfills.js', 1),
#  ('functions.js', 1),
#  ('ol3-layerswitcher.js', 1),
#  ('2_2.js', 1),
#  ('bootstrap-datepicker.kr.js', 1),
#  ('jquery.bxslider.min.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('imagesloaded.pkgd.min.js', 1),
#  ('dqAutoCompleteCommon.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('main.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('ace-extra.min.js', 1),
#  ('jquery-1.11.0.min.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('nav.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('dqMainAutoComplete.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('jquery-ui.min.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('popup.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('dqMainAutoComplete.js', 1),
#  ('bootstrap-datepicker.js', 1),
#  ('slick.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('moment-with-locales.min.js', 1),
#  ('header.js;jsessionid=t9skks0rA7rMpDbjFGU3P-Vd.node20', 1),
#  ('rolling', 1),
#  ('jquery.placeholder.js', 1),
#  ('jquery.selectric.js', 1),
#  ('map', 1),
#  ('ntic.js', 1),
#  ('maps.js?clientId=TnPvGUmhPj6ChSJZovU6&submodules=panorama,geocoder', 1),
#  ('design.js', 1),
#  ('ntis.js', 1),
#  ('jquery-1.11.1.js', 1),
#  ('lsLink.js', 1),
#  ('CookieUtil.js', 1),
#  ('jquery-custom.js', 1),
#  ('etcUtils.js', 1),
#  ('jquery.loadmask.js', 1),
#  ('ls.js', 1),
#  ('json', 1),
#  ('drag_search.js', 1),
#  ('jquery-ui_2017.js', 1),
#  ('jquery.layout-latest.js', 1),
#  ('main.js?Time=1543363971', 1),
#  ('img-common.js', 1),
#  ('tree.js', 1),
#  ('jquery.cookie.min.js', 1),
#  ('jquery.simplePagination.js', 1),
#  ('jquery.print.js', 1),
#  ('highlight.pack.js', 1),
#  ('bootstrap.min.js', 1),
#  ('e-book', 1),
#  ('jquery.fancybox.js', 1),
#  ('jquery.navgoco.min.js', 1),
#  ('search_autocomplete_common.js', 1),
#  ('button.js', 1),
#  ('css3-mediaqueries.js', 1),
#  ('collapse.js', 1),
#  ('spin.min.js', 1),
#  ('jquery.nivo.slider.min.js', 1),
#  ('jquery.sidr.min.js', 1),
#  ('jquery.selecter.min.js', 1),
#  ('ssbs', 1),
#  ('jquery.sharer.js', 1),
#  ('validator.do', 1),
#  ('validator.do;jsessionid=2ovVqqCCPbBz29FSyRAkd2ZkRH0YYQFeFRUgu3iG8NBW5oOt00hQNH7r6HloWKHm.frswas02_servlet_engine1',
#   1),
#  ('nppfs.script-1.6.0.jsp', 1),
#  ('connect.facebook.net', 1),
#  ('ko_KR', 1),
#  ('all.js', 1),
#  ('calendarPopup.js', 1),
#  ('116.67.84.152', 1),
#  ('portalo', 1),
#  ('widget', 1),
#  ('frfrInfoNow.js', 1),
#  ('2012', 1),
#  ('content2.js', 1),
#  ('cop', 1),
#  ('EgovBBSMng.js', 1),
#  ('validator.do;jsessionid=Z7d6NXlN1QfLEjb8yYHjMqTymVZCDHJYFFFNafWaUZAWaE5y0sV13Y14scvQ5vXM.frswas02_servlet_engine1',
#   1),
#  ('guide.js', 1),
#  ('layout_main.js', 1),
#  ('jquery-1.6.2.min.js;jsessionid=SBEbbpiAsPXCMID5w5q9LarDH74vudarFeOFyXz866Js7bHa0lJVqE9XqRCsFiCa.g4bap2_servlet_engine1',
#   1),
#  ('g4b.js;jsessionid=SBEbbpiAsPXCMID5w5q9LarDH74vudarFeOFyXz866Js7bHa0lJVqE9XqRCsFiCa.g4bap2_servlet_engine1',
#   1),
#  ('CmmUtil.js;jsessionid=SBEbbpiAsPXCMID5w5q9LarDH74vudarFeOFyXz866Js7bHa0lJVqE9XqRCsFiCa.g4bap2_servlet_engine1',
#   1),
#  ('jquery-1.6.2.min.js;jsessionid=ynl34hBnb72K1oZ2CCa2CQnTxwg3tejjFRaaE4F0r2PJXig607ZZjCA9tb6Uuxeu.g4bap2_servlet_engine1',
#   1),
#  ('xecureweb.js;jsessionid=SBEbbpiAsPXCMID5w5q9LarDH74vudarFeOFyXz866Js7bHa0lJVqE9XqRCsFiCa.g4bap2_servlet_engine1',
#   1),
#  ('JControl.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap2_servlet_engine1',
#   1),
#  ('xecureweb.js;jsessionid=ynl34hBnb72K1oZ2CCa2CQnTxwg3tejjFRaaE4F0r2PJXig607ZZjCA9tb6Uuxeu.g4bap2_servlet_engine1',
#   1),
#  ('cmm.js', 1),
#  ('etc.js', 1),
#  ('g4b.js;jsessionid=ynl34hBnb72K1oZ2CCa2CQnTxwg3tejjFRaaE4F0r2PJXig607ZZjCA9tb6Uuxeu.g4bap2_servlet_engine1',
#   1),
#  ('CmmUtil.js;jsessionid=ynl34hBnb72K1oZ2CCa2CQnTxwg3tejjFRaaE4F0r2PJXig607ZZjCA9tb6Uuxeu.g4bap2_servlet_engine1',
#   1),
#  ('xecureweb.js;jsessionid=hugPWTaUACHpYpQrUW1qDWck9ntbjoRQFPqt14msVUacQ1s10B1dDjSAQOk1BKAW.g4bap1_servlet_engine1',
#   1),
#  ('xecureweb.js;jsessionid=9lReZcqXh0XANOevgycjceYdeBTVveAtFCogLbSs1vlMdYAr0mV52u796brHzaDt.g4bap1_servlet_engine1',
#   1),
#  ('xecureweb.js;jsessionid=qTXi8I1cJUfsjD1CycBssLweeM15GtTEFwQooTE5gD2Pi3Q30jkyPz0q2EP1YDWe.g4bap1_servlet_engine1',
#   1),
#  ('respond.min.js', 1),
#  ('jquery.slides2.min.js', 1),
#  ('jquery.carousell-1.0.js', 1),
#  ('jquery.carouFredSel-3.2.1-packed.js', 1),
#  ...]

# %%
js_files.loc[js_files['jsFile'].str.contains('bootstrap')][['netLoc', 'jsFile']]
# Out:
#                                 netLoc  \
# 634              http://www.moef.go.kr
# 658              http://www.moef.go.kr
# 698  https://www.foodsafetykorea.go.kr
# 705  https://www.foodsafetykorea.go.kr
# 706  https://www.foodsafetykorea.go.kr
# 712  https://www.foodsafetykorea.go.kr
# 722  https://www.foodsafetykorea.go.kr
# 860              https://www.nts.go.kr
#
#                                        jsFile
# 634  /js/date-time/bootstrap-datepicker.kr.js
# 658     /js/date-time/bootstrap-datepicker.js
# 698               /js/bootstrap/datepicker.js
# 705                      /js/bootstrap/tab.js
# 706                      /js/bootstrap.min.js
# 712                   /js/bootstrap/button.js
# 722                 /js/bootstrap/collapse.js
# 860             /js/jquery-modal/bootstrap.js

# %%
js_files_1 = remove_js_file_contain_keyword(js_files, 'jquery'); len(js_files_1)  # 94142
# Out:
# 1388

# %%
# js_files_1 = remove_js_file_contain_keyword(js_files_1, '.min.') # 89416
# print(len(js_files_1))

# %%
js_files_1 = remove_js_file_contain_keyword(js_files_1, 'prototype.js'); len(js_files_1) # 88945
# Out:
# 1385

# %%
js_files_2 = js_files_1.drop(columns=['_id']); js_files_2
# Out:
#                                                  jsFile  \
# 3                                    /js/html5.js?ver=2
# 5                               /js/modernizr.custom.js
# 6                                         /js/common.js
# 7                                     /js/search_btn.js
# 8                                        /js/classie.js
# 9                                     /js/navigation.js
# 10    https://www.googletagmanager.com/gtag/js?id=UA...
# 15    https://127.0.0.1:49767/ntum/reqeust?callback=...
# 17    /client/crevit_setup/crevit/deploy/OID-2017111...
# 18                        /js/common/AxDSMSecureAuth.js
# 19                       /ab/js/common/security_main.js
# 20      /js/common/magicline4np/magicline.js?v=20171114
# 21                            /ab/js/common/security.js
# 22                            /ab/js/common/ab080com.js
# 23                            /ab/js/common/abcommon.js
# 24                           /ab/js/common/abmessage.js
# 26                            /js/common/nppfs-2.0.0.js
# 28                           /gpkisecureweb/certLoin.js
# 34               /nportal/resource/html/js/html5shiv.js
# 35                      /nportal/resource/html/js/ui.js
# 36                  /nportal/resource/html/js/police.js
# 39       /nportal/resource/html/js/i9ResoponseVoice2.js
# 41                 /nportal/resource/html/js/iscroll.js
# 42                                     /comm/js/xjsv.js
# 43    /js/minwon/search/AA090_eissue_apply_list.js?v...
# 44              ./js/minwon_isp/common/minwon_common.js
# 45               /js/minwon_isp/common/minwon_common.js
# 46                   /AnySign4PC/anySign4PCInterface.js
# 48                             /js/common/leecomUtil.js
# 49                         /js/common/common_topmenu.js
# ...                                                 ...
# 1921                                  /js/react/main.js
# 1923                             /js/react/mwsuggest.js
# 1924                       /js/react/lightslider.min.js
# 1925                                /js/react/common.js
# 1926  https://hisimpan.mohw.go.kr/sp2/web2/js/autota...
# 1927                           /XuniObject/xecureweb.js
# 1928  https://hisimpan.mohw.go.kr/sp2/web2/js/common.js
# 1930          /js/yessignCert/yessignCrypto.js?20171116
# 1931         /js/yessignCert/yessignInstall.js?20171116
# 1932         /js/yessignCert/yessign-nppfs-1.3.0.min.js
# 1933                      /js/pluginfree/nppfs-1.9.0.js
# 1934             /js/pluginfree/nppfs.addon.js?20171116
# 1935             /js/yessignCert/TouchEnKey.js?20160107
# 1936                 /common/pluginfree/nppfs.script.do
# 1937            /js/yessignCert/yessignUtil.js?20160416
# 1940                 /comm/pluginfree/js/nppfs-1.9.0.js
# 1941               /comm/AnySign/anySign4PCInterface.js
# 1943       /js/AnySign/AnySign4PC/ext/AnySign4PC_min.js
# 1944                           ../veraport20_handler.js
# 1945                        /portal/js/zva_quickmenu.js
# 1947                /portal/jslib/form_state_manager.js
# 1948                              install_config_doc.js
# 1949                                /portal/js/embed.js
# 1951                 /js/AnySign/anySign4PCInterface.js
# 1952                               /portal/js/common.js
# 1953                             ../veraport20_multi.js
# 1954                                install_internal.js
# 1956                             /portal/js/zva_comm.js
# 1957                                   ../veraport20.js
# 1958          /js/AnySign/AnySign4PC/ext/SecureProto.js
#
#                            netLoc
# 3      http://www.president.go.kr
# 5      http://www.president.go.kr
# 6      http://www.president.go.kr
# 7      http://www.president.go.kr
# 8      http://www.president.go.kr
# 9      http://www.president.go.kr
# 10     http://www.president.go.kr
# 15         http://www.share.go.kr
# 17         http://www.share.go.kr
# 18         http://www.share.go.kr
# 19         http://www.share.go.kr
# 20         http://www.share.go.kr
# 21         http://www.share.go.kr
# 22         http://www.share.go.kr
# 23         http://www.share.go.kr
# 24         http://www.share.go.kr
# 26         http://www.share.go.kr
# 28         http://www.share.go.kr
# 34        http://www.police.go.kr
# 35        http://www.police.go.kr
# 36        http://www.police.go.kr
# 39        http://www.police.go.kr
# 41        http://www.police.go.kr
# 42        http://www.minwon.go.kr
# 43        http://www.minwon.go.kr
# 44        http://www.minwon.go.kr
# 45        http://www.minwon.go.kr
# 46        http://www.minwon.go.kr
# 48        http://www.minwon.go.kr
# 49        http://www.minwon.go.kr
# ...                           ...
# 1921        http://www.mohw.go.kr
# 1923        http://www.mohw.go.kr
# 1924        http://www.mohw.go.kr
# 1925        http://www.mohw.go.kr
# 1926  https://hisimpan.mohw.go.kr
# 1927  https://hisimpan.mohw.go.kr
# 1928  https://hisimpan.mohw.go.kr
# 1930       https://www.giro.or.kr
# 1931       https://www.giro.or.kr
# 1932       https://www.giro.or.kr
# 1933       https://www.giro.or.kr
# 1934       https://www.giro.or.kr
# 1935       https://www.giro.or.kr
# 1936       https://www.giro.or.kr
# 1937       https://www.giro.or.kr
# 1940    https://www.bokjiro.go.kr
# 1941    https://www.bokjiro.go.kr
# 1943        http://www.kics.go.kr
# 1944        http://www.kics.go.kr
# 1945        http://www.kics.go.kr
# 1947        http://www.kics.go.kr
# 1948        http://www.kics.go.kr
# 1949        http://www.kics.go.kr
# 1951        http://www.kics.go.kr
# 1952        http://www.kics.go.kr
# 1953        http://www.kics.go.kr
# 1954        http://www.kics.go.kr
# 1956        http://www.kics.go.kr
# 1957        http://www.kics.go.kr
# 1958        http://www.kics.go.kr
#
# [1385 rows x 2 columns]

# %%
with MyMongo() as db:
    db.delete_and_insert_df('public_website', 'c4_js_files_processed', js_files_2)
# Out:
# <--Mongo Connected.
# {}
# Deleted rows: 1281
# Inserted rows: 1385
# Mongo Connection Closed.-->

# %% [markdown]
# # Import

# %%
import pandas as pd
from db.mongo import MyMongo

# %% [markdown]
# # Load Data

# %%
with MyMongo() as db:
    external = db.get_df_from_table('public_website', 'a6_ax_exe_external')
    in_page = db.get_df_from_table('public_website', 'b1_a1_ax_exe_in_page')
    website = db.get_df_from_table('public_website', 'website_all')
# Out:
# <--Mongo Connected.
# Mongo Connection Closed.-->

# %% [markdown]
# # Index and Columns

# %%
# idx_ext_ax = external['ax_code'].apply(lambda x: bool(len(x)))
idx_ext_ax = list(map(lambda x: bool(len(x)), external['ax_code']))
idx_ext_exe = list(map(lambda x: bool(len(x)), external['exe_code']))
idx_in_ax = list(map(lambda x: bool(len(x)), in_page['ax_code']))
idx_in_exe = list(map(lambda x: bool(len(x)), in_page['exe_code']))

# %%
cols_code = ['url', 'ax_code', 'exe_code']
cols_file = ['url', 'ax_file', 'exe_file']

# %% [markdown]
# # Functions

# %%
def split_list_and_get_file_name(li):
    return [l.split('/')[-1] for l in li]

# %% [markdown]
# # Transform

# %% [markdown]
# ## Split List and Get File Name

# %%
external['ax_file'] = external['ax_code'].apply(split_list_and_get_file_name)
external['exe_file'] = external['exe_code'].apply(split_list_and_get_file_name)
in_page['ax_file'] = in_page['ax_code'].apply(split_list_and_get_file_name)
in_page['exe_file'] = in_page['exe_code'].apply(split_list_and_get_file_name)

# %% [markdown]
# ## Expand list to df

# %%
# from itertools import zip_longest
# a = 1
# b = [2,3]
# list(zip_longest([a], b, fillvalue=a))
# input df output df
def make_expanded_df_from_list_df(list_df, col_name):
    from itertools import zip_longest
    result = []
    for i, row in list_df.iterrows():
        url = row['url']
        files = row[col_name]
        if files:
            tmp = list(zip_longest([url], files, fillvalue=url))
            result.extend(tmp)
    return pd.DataFrame(columns=['url', col_name], data=result)

# %%
df_ext_ax_expanded = make_expanded_df_from_list_df(external.loc[idx_ext_ax, ['url', 'ax_file']], 'ax_file')
df_ext_exe_expanded = make_expanded_df_from_list_df(external.loc[idx_ext_exe, ['url', 'exe_file']], 'exe_file')
df_in_ax_expanded = make_expanded_df_from_list_df(in_page.loc[idx_in_ax, ['url', 'ax_file']], 'ax_file')
df_in_exe_expanded = make_expanded_df_from_list_df(in_page.loc[idx_in_exe, ['url', 'exe_file']], 'exe_file')

# %% [markdown]
# ## Add domain

# %%
from urllib.parse import urlsplit
# df_ext_ax_expanded.loc[::,['domain', 'path']] = df_ext_ax_expanded['url'].apply(lambda x: urlsplit(x)[1:3])
df_ext_ax_expanded['domain'] = df_ext_ax_expanded['url'].apply(lambda x: urlsplit(x)[1])
df_ext_ax_expanded['path'] = df_ext_ax_expanded['url'].apply(lambda x: urlsplit(x)[2])

df_ext_exe_expanded['domain'] = df_ext_exe_expanded['url'].apply(lambda x: urlsplit(x)[1])
df_ext_exe_expanded['path'] = df_ext_exe_expanded['url'].apply(lambda x: urlsplit(x)[2])

df_in_ax_expanded['domain'] = df_in_ax_expanded['url'].apply(lambda x: urlsplit(x)[1])
df_in_ax_expanded['path'] = df_in_ax_expanded['url'].apply(lambda x: urlsplit(x)[2])

df_in_exe_expanded['domain'] = df_in_exe_expanded['url'].apply(lambda x: urlsplit(x)[1])
df_in_exe_expanded['path'] = df_in_exe_expanded['url'].apply(lambda x: urlsplit(x)[2])
# df_ext_ax_expanded['domain'] = df_ext_ax_expanded['url']

# %% [markdown]
# ## Add Name & Description

# %%
def add_name_and_description(df):
    for i, row in df.iterrows():
        domain = row['domain']
        found = website.loc[website['url'].str.contains(domain)]
        if len(found):
            df.at[i, 'name'] = found.iloc[0]['name']
            df.at[i, 'description'] = found.iloc[0]['description']

# %%
add_name_and_description(df_ext_exe_expanded)
add_name_and_description(df_ext_ax_expanded)
add_name_and_description(df_in_exe_expanded)
add_name_and_description(df_in_ax_expanded)

# %% [markdown]
# ### Index and Columns

# %%
cols_domain_ax = ['domain', 'name', 'path', 'ax_file']
cols_domain_exe = ['domain', 'name', 'path', 'exe_file']

# %%
idx_ext_exe_gov = df_ext_exe_expanded['domain']=='www.gov.kr'
idx_ext_ax_gov = df_ext_ax_expanded['domain']=='www.gov.kr'

# %% [markdown]
# ## Groupby domain

# %%
grp_ext_exe = df_ext_exe_expanded.groupby('domain').agg('count').sort_values('exe_file', ascending=False)
grp_in_exe = df_in_exe_expanded.groupby('domain').agg('count').sort_values('exe_file', ascending=False)

grp_ext_ax = df_ext_ax_expanded.groupby('domain').agg('count').sort_values('ax_file', ascending=False)
grp_in_ax = df_in_ax_expanded.groupby('domain').agg('count').sort_values('ax_file', ascending=False)

# %% [markdown]
# # Border ---------------------------------

# %%
df_ext_exe_expanded.head()
# Out:
#                                                  url  \
# 0  http://www.kops.or.kr/AnySign/anySign4PCInterf...
# 1  http://www.kops.or.kr/AnySign/anySign4PCInterf...
# 2  http://www.kops.or.kr/AnySign/anySign4PCInterf...
# 3  http://gangwon.childcare.go.kr/html/Xecure/xec...
# 4  http://gangwon.childcare.go.kr/html/Xecure/xec...
#
#                         exe_file                   domain  \
# 0               hConvert2pfx.exe           www.kops.or.kr
# 1  xwcup_install_windows_x64.exe           www.kops.or.kr
# 2  xwcup_install_windows_x86.exe           www.kops.or.kr
# 3  xwcup_install_windows_x64.exe  gangwon.childcare.go.kr
# 4  xwcup_install_windows_x86.exe  gangwon.childcare.go.kr
#
#                               path             name  \
# 0  /AnySign/anySign4PCInterface.js  환자안전 보고학습시스템 포털
# 1  /AnySign/anySign4PCInterface.js  환자안전 보고학습시스템 포털
# 2  /AnySign/anySign4PCInterface.js  환자안전 보고학습시스템 포털
# 3     /html/Xecure/xecureweb_up.js      강원도육아종합지원센터
# 4     /html/Xecure/xecureweb_up.js      강원도육아종합지원센터
#
#                                          description
# 0                               환자안전 보고학습시스템 업무포털시스템
# 1                               환자안전 보고학습시스템 업무포털시스템
# 2                               환자안전 보고학습시스템 업무포털시스템
# 3  강원도육아종합지원센터의 홈페이지로 센터 소개, 영유아가정지원, 어린이집지원, 정보마...
# 4  강원도육아종합지원센터의 홈페이지로 센터 소개, 영유아가정지원, 어린이집지원, 정보마...

# %%
df_ext_exe_expanded.loc[idx_ext_exe_gov]
# Out:
#                                                    url  \
# 120  http://www.gov.kr/webPlugins/nlogin/AnySign4PC...
# 121  http://www.gov.kr/webPlugins/nlogin/AnySign4PC...
# 122   http://www.gov.kr/wizvera/veraport/veraport20.js
# 123   http://www.gov.kr/wizvera/veraport/veraport20.js
# 124   http://www.gov.kr/wizvera/veraport/veraport20.js
# 125   http://www.gov.kr/wizvera/veraport/veraport20.js
#
#                           exe_file      domain  \
# 120  xwcup_install_windows_x64.exe  www.gov.kr
# 121  xwcup_install_windows_x86.exe  www.gov.kr
# 122            veraport-g3-x64.exe  www.gov.kr
# 123       veraport-g3-x64-sha2.exe  www.gov.kr
# 124                veraport-g3.exe  www.gov.kr
# 125           veraport-g3-sha2.exe  www.gov.kr
#
#                                                   path  name  \
# 120  /webPlugins/nlogin/AnySign4PC/anySign4PCInterf...  정부24
# 121  /webPlugins/nlogin/AnySign4PC/anySign4PCInterf...  정부24
# 122                    /wizvera/veraport/veraport20.js  정부24
# 123                    /wizvera/veraport/veraport20.js  정부24
# 124                    /wizvera/veraport/veraport20.js  정부24
# 125                    /wizvera/veraport/veraport20.js  정부24
#
#                                       description
# 120  정부24 홈페이지로 정부서비스, 민원서비스, 정책정보 등의 서비스를 제공합니다.
# 121  정부24 홈페이지로 정부서비스, 민원서비스, 정책정보 등의 서비스를 제공합니다.
# 122  정부24 홈페이지로 정부서비스, 민원서비스, 정책정보 등의 서비스를 제공합니다.
# 123  정부24 홈페이지로 정부서비스, 민원서비스, 정책정보 등의 서비스를 제공합니다.
# 124  정부24 홈페이지로 정부서비스, 민원서비스, 정책정보 등의 서비스를 제공합니다.
# 125  정부24 홈페이지로 정부서비스, 민원서비스, 정책정보 등의 서비스를 제공합니다.

# %%
df_ext_ax_expanded.loc[idx_ext_ax_gov, cols_domain_ax]
# Out:
#         domain                                               path  \
# 75  www.gov.kr  /webPlugins/nlogin/AnySign4PC/anySign4PCInterf...
# 76  www.gov.kr  /webPlugins/nlogin/AnySign4PC/anySign4PCInterf...
# 77  www.gov.kr                    /wizvera/veraport/veraport20.js
# 78  www.gov.kr                    /wizvera/veraport/veraport20.js
# 79  www.gov.kr                    /wizvera/veraport/veraport20.js
# 80  www.gov.kr                    /wizvera/veraport/veraport20.js
#
#                           ax_file
# 75  xwcup_install_windows_x86.cab
# 76  xwcup_install_windows_x64.cab
# 77        veraport20-x64-sha2.cab
# 78             veraport20-x64.cab
# 79            veraport20-sha2.cab
# 80                 veraport20.cab

# %%
# grp_ext_exe.loc[grp_ext_exe['url']==1].index
df_ext_exe_expanded.merge(grp_ext_exe.loc[grp_ext_exe['url']==1, ['path']], left_on='domain', right_index=True, how='inner')
# Out:
#                                                    url  \
# 5        http://museum.navy.ac.kr/common/js/embedJs.js
# 6    http://klis.jeonnam.go.kr/sis/gpkisecureweb/va...
# 7             http://www.cne.go.kr/kcase/EPKICommon.js
# 8    http://www.cntae.go.kr/include/EPKI/kcase/EPKI...
# 29   http://www.cnssed.go.kr/include/EPKI/kcase/EPK...
# 30         http://gdoc.go.kr/gpki/gpkisecureweb/var.js
# 34    http://jangyubranch.gimhae.go.kr/share/js/all.js
# 35       http://hnrl.namgu.incheon.kr/js/usr/common.js
# 42              http://www.bppl.or.kr/js/usr/common.js
# 43    http://tour.gimje.go.kr/wenUploader/wenplayer.js
# 44   http://lifemap.busan.go.kr/js/egovframework/co...
# 45      http://hidigp.seoul.go.kr/gpkisecureweb/var.js
# 52         http://www.barotalk.kr/gpkisecureweb/var.js
# 55   http://www.hs-support.go.kr/js/egovframework/c...
# 56   http://www.knpgun.go.kr/initech/plugin/install.js
# 57         http://www.pifrs.go.kr/gpkisecureweb/var.js
# 60   http://www.budamgum.or.kr/res/lib/signkorea/js...
# 67               http://cheongma.or.kr/share/js/all.js
# 71   http://real.shlib.or.kr/include/EPKI/kcase/EPK...
# 72   http://www.cngje.go.kr/include/EPKI/kcase/EPKI...
# 73                http://cne.go.kr/kcase/EPKICommon.js
# 74   http://special.cngje.go.kr/include/EPKI/kcase/...
# 75   http://sp.cnased.go.kr/include/EPKI/kcase/EPKI...
# 76   http://archive.cncae.go.kr/include/EPKI/kcase/...
# 77            http://www.dje.go.kr/kcase/EPKICommon.js
# 80         http://ghyouth.gimhae.go.kr/share/js/all.js
# 85     http://satp.goe.go.kr/./ksign/kcase/kcaseapi.js
# 86             http://biz.gimhae.go.kr/share/js/all.js
# 87            http://bike.gimhae.go.kr/share/js/all.js
# 90         http://wems.nier.go.kr/gpkisecureweb/var.js
# ..                                                 ...
# 102          http://www.lawmaking.go.kr/js/gpki/var.js
# 103  http://value.fact.or.kr/XecureObject/xecureweb.js
# 110         http://info.korail.com/softcamp/secukey.js
# 112        http://www.gims.go.kr/js/igis/global_val.js
# 113  http://www.navylogicom.mil.kr/common/js/embedJ...
# 114    http://welfare.navy.mil.kr/common/js/embedJs.js
# 119      http://www.lost112.go.kr/gpkisecureweb/var.js
# 129  http://www.yisseoul.org/bundles/js?v=dzemRdYjB...
# 130                 http://www.dhc.ac.kr/_js/common.js
# 131         http://www.navy.ac.kr/common/js/embedJs.js
# 132      http://login.kongju.ac.kr/kcase/EPKICommon.js
# 133      http://www.imla.kr/js/usr/imla/imla_common.js
# 140  http://www.cnyse.go.kr/include/EPKI/kcase/EPKI...
# 141  http://www.cnhsed.go.kr/include/EPKI/kcase/EPK...
# 142  http://www.cnased.go.kr/include/EPKI/kcase/EPK...
# 143  http://www.cncae.go.kr/include/EPKI/kcase/EPKI...
# 144  http://www.cifle.go.kr/include/EPKI/kcase/EPKI...
# 145  http://www.cnbl.or.kr/include/EPKI/kcase/EPKIC...
# 146  http://www.cle.or.kr/include/EPKI/kcase/EPKICo...
# 147  http://www.cnsec.or.kr/include/EPKI/kcase/EPKI...
# 152  http://sti.kostat.go.kr/coresti/GPKI/gpkisecur...
# 155  http://www.cnbye.go.kr/include/EPKI/kcase/EPKI...
# 156  http://www.cngse.go.kr/include/EPKI/kcase/EPKI...
# 164  http://tia.molit.go.kr/templet/gpkisecureweb/v...
# 165        http://etas.ts2020.kr/js/etas/etasCommon.js
# 166  http://minwon.kma.go.kr/XecureObject/xecureweb.js
# 167      http://admin.alio.go.kr/js/initech/install.js
# 168  http://dais.karts.ac.kr/./WebCube/WebCubeAgent.js
# 169   http://minwon.nps.or.kr/XecureObject/CKKeyPro.js
# 170  http://www.foodsafetykorea.go.kr/gpkiweb/insta...
#
#                                               exe_file  \
# 5                                 wmpfirefoxplugin.exe
# 6                             install_off_v1.0.4.9.exe
# 7                     KCaseAgent_Installer_v1.3.13.exe
# 8                             KCaseAgent_Installer.exe
# 29                            KCaseAgent_Installer.exe
# 30                            install_off_v1.0.4.9.exe
# 34                   jre-1_5_0_11-windows-i586-p-s.exe
# 35                                wmpfirefoxplugin.exe
# 42                                wmpfirefoxplugin.exe
# 43                   flashplayer11_9r900_170_winax.exe
# 44                                  GPKISecureWebX.exe
# 45                                  GPKISecureWebX.exe
# 52                                  GPKISecureWebX.exe
# 55                                  GPKISecureWebX.exe
# 56                                          INIS60.exe
# 57                                  GPKISecureWebX.exe
# 60                    SKCertServiceSetup_v2.4.5_61.exe
# 67                   jre-1_5_0_11-windows-i586-p-s.exe
# 71                            KCaseAgent_Installer.exe
# 72                            KCaseAgent_Installer.exe
# 73                    KCaseAgent_Installer_v1.3.13.exe
# 74                            KCaseAgent_Installer.exe
# 75                            KCaseAgent_Installer.exe
# 76                            KCaseAgent_Installer.exe
# 77                     KCaseAgent_Installer_v1.3.6.exe
# 80                   jre-1_5_0_11-windows-i586-p-s.exe
# 85                            KCaseAgent_Installer.exe
# 86                   jre-1_5_0_11-windows-i586-p-s.exe
# 87                   jre-1_5_0_11-windows-i586-p-s.exe
# 90                                  GPKISecureWebX.exe
# ..                                                 ...
# 102                                 GPKISecureWebX.exe
# 103                                     xw_install.exe
# 110                                   SCSKVXULInst.exe
# 112                                       SisunGIS.exe
# 113                               wmpfirefoxplugin.exe
# 114                               wmpfirefoxplugin.exe
# 119                                 GPKISecureWebX.exe
# 129                                           ^.*\.exe
# 130                                           smsx.exe
# 131                               wmpfirefoxplugin.exe
# 132                             KSignClient_v1.3.9.exe
# 133                               wmpfirefoxplugin.exe
# 140                    KCaseAgent_Installer_v1.3.6.exe
# 141                           KCaseAgent_Installer.exe
# 142                           KCaseAgent_Installer.exe
# 143                           KCaseAgent_Installer.exe
# 144                           KCaseAgent_Installer.exe
# 145                           KCaseAgent_Installer.exe
# 146                           KCaseAgent_Installer.exe
# 147                           KCaseAgent_Installer.exe
# 152                                 GPKISecureWebX.exe
# 155                           KCaseAgent_Installer.exe
# 156                           KCaseAgent_Installer.exe
# 164                                 GPKISecureWebX.exe
# 165  ^(([a-zA-Z]:)|(\\{2}\w+)\$?)(\\(\w[\w].*))+(.j...
# 166                                     xw_install.exe
# 167                                         INIS60.exe
# 168                              WebCubeAgentSetup.exe
# 169     TouchEnKey_Installer3.1.0.16_32bit_allkill.exe
# 170                                 GPKISecureWebX.exe
#
#                         domain  \
# 5            museum.navy.ac.kr
# 6           klis.jeonnam.go.kr
# 7                www.cne.go.kr
# 8              www.cntae.go.kr
# 29            www.cnssed.go.kr
# 30                  gdoc.go.kr
# 34   jangyubranch.gimhae.go.kr
# 35       hnrl.namgu.incheon.kr
# 42              www.bppl.or.kr
# 43            tour.gimje.go.kr
# 44         lifemap.busan.go.kr
# 45          hidigp.seoul.go.kr
# 52             www.barotalk.kr
# 55        www.hs-support.go.kr
# 56            www.knpgun.go.kr
# 57             www.pifrs.go.kr
# 60          www.budamgum.or.kr
# 67              cheongma.or.kr
# 71            real.shlib.or.kr
# 72             www.cngje.go.kr
# 73                   cne.go.kr
# 74         special.cngje.go.kr
# 75             sp.cnased.go.kr
# 76         archive.cncae.go.kr
# 77               www.dje.go.kr
# 80        ghyouth.gimhae.go.kr
# 85              satp.goe.go.kr
# 86            biz.gimhae.go.kr
# 87           bike.gimhae.go.kr
# 90             wems.nier.go.kr
# ..                         ...
# 102        www.lawmaking.go.kr
# 103           value.fact.or.kr
# 110            info.korail.com
# 112             www.gims.go.kr
# 113     www.navylogicom.mil.kr
# 114        welfare.navy.mil.kr
# 119          www.lost112.go.kr
# 129           www.yisseoul.org
# 130              www.dhc.ac.kr
# 131             www.navy.ac.kr
# 132         login.kongju.ac.kr
# 133                www.imla.kr
# 140            www.cnyse.go.kr
# 141           www.cnhsed.go.kr
# 142           www.cnased.go.kr
# 143            www.cncae.go.kr
# 144            www.cifle.go.kr
# 145             www.cnbl.or.kr
# 146              www.cle.or.kr
# 147            www.cnsec.or.kr
# 152           sti.kostat.go.kr
# 155            www.cnbye.go.kr
# 156            www.cngse.go.kr
# 164            tia.molit.go.kr
# 165             etas.ts2020.kr
# 166           minwon.kma.go.kr
# 167           admin.alio.go.kr
# 168           dais.karts.ac.kr
# 169           minwon.nps.or.kr
# 170  www.foodsafetykorea.go.kr
#
#                                                 path_x  path_y
# 5                                /common/js/embedJs.js       1
# 6                            /sis/gpkisecureweb/var.js       1
# 7                                 /kcase/EPKICommon.js       1
# 8                    /include/EPKI/kcase/EPKICommon.js       1
# 29                   /include/EPKI/kcase/EPKICommon.js       1
# 30                          /gpki/gpkisecureweb/var.js       1
# 34                                    /share/js/all.js       1
# 35                                   /js/usr/common.js       1
# 42                                   /js/usr/common.js       1
# 43                           /wenUploader/wenplayer.js       1
# 44   /js/egovframework/com/uat/uia/EgovGpkiVariable...       1
# 45                               /gpkisecureweb/var.js       1
# 52                               /gpkisecureweb/var.js       1
# 55   /js/egovframework/com/uat/uia/EgovGpkiVariable...       1
# 56                          /initech/plugin/install.js       1
# 57                               /gpkisecureweb/var.js       1
# 60                     /res/lib/signkorea/js/koscom.js       1
# 67                                    /share/js/all.js       1
# 71                   /include/EPKI/kcase/EPKICommon.js       1
# 72                   /include/EPKI/kcase/EPKICommon.js       1
# 73                                /kcase/EPKICommon.js       1
# 74                   /include/EPKI/kcase/EPKICommon.js       1
# 75                   /include/EPKI/kcase/EPKICommon.js       1
# 76                   /include/EPKI/kcase/EPKICommon.js       1
# 77                                /kcase/EPKICommon.js       1
# 80                                    /share/js/all.js       1
# 85                          /./ksign/kcase/kcaseapi.js       1
# 86                                    /share/js/all.js       1
# 87                                    /share/js/all.js       1
# 90                               /gpkisecureweb/var.js       1
# ..                                                 ...     ...
# 102                                    /js/gpki/var.js       1
# 103                         /XecureObject/xecureweb.js       1
# 110                               /softcamp/secukey.js       1
# 112                             /js/igis/global_val.js       1
# 113                              /common/js/embedJs.js       1
# 114                              /common/js/embedJs.js       1
# 119                              /gpkisecureweb/var.js       1
# 129                                        /bundles/js       1
# 130                                     /_js/common.js       1
# 131                              /common/js/embedJs.js       1
# 132                               /kcase/EPKICommon.js       1
# 133                        /js/usr/imla/imla_common.js       1
# 140                  /include/EPKI/kcase/EPKICommon.js       1
# 141                  /include/EPKI/kcase/EPKICommon.js       1
# 142                  /include/EPKI/kcase/EPKICommon.js       1
# 143                  /include/EPKI/kcase/EPKICommon.js       1
# 144                  /include/EPKI/kcase/EPKICommon.js       1
# 145                  /include/EPKI/kcase/EPKICommon.js       1
# 146                  /include/EPKI/kcase/EPKICommon.js       1
# 147                  /include/EPKI/kcase/EPKICommon.js       1
# 152  /coresti/GPKI/gpkisecureweb/JSP/gpkisecureweb/...       1
# 155                  /include/EPKI/kcase/EPKICommon.js       1
# 156                  /include/EPKI/kcase/EPKICommon.js       1
# 164                      /templet/gpkisecureweb/var.js       1
# 165                             /js/etas/etasCommon.js       1
# 166                         /XecureObject/xecureweb.js       1
# 167                             /js/initech/install.js       1
# 168                         /./WebCube/WebCubeAgent.js       1
# 169                          /XecureObject/CKKeyPro.js       1
# 170                            /gpkiweb/install/var.js       1
#
# [67 rows x 5 columns]

# %%
grp_ext_exe.merge(grp_in_exe, right_index=True, left_index=True)
# Out:
#                       url_x  exe_file_x  path_x  url_y  exe_file_y  path_y
# domain
# www.hs-support.go.kr      1           1       1      1           1       1

# %%
grp_ext_ax.merge(grp_in_ax, right_index=True, left_index=True)
# Out:
#                   url_x  ax_file_x  path_x  url_y  ax_file_y  path_y
# domain
# minwon.nps.or.kr      2          2       2      2          2       2

# %%
grp_ext_exe
# Out:
#                            url  exe_file  path  name  description
# domain
# www.gov.kr                   6         6     6     6            6
# exim.allbaro.or.kr           4         4     4     4            4
# total.kcomwel.or.kr          3         3     3     3            3
# www.efine.go.kr              3         3     3     3            3
# apply.lh.or.kr               3         3     3     3            3
# ebid.kr.or.kr                3         3     3     3            3
# ebid.knoc.co.kr              3         3     3     3            3
# water-pos.kwater.or.kr       3         3     3     3            3
# www.kops.or.kr               3         3     3     3            3
# cont.kisa.or.kr              3         3     3     3            3
# www.humanrights.go.kr        2         2     2     2            2
# www.kcti.re.kr               2         2     2     2            2
# lifetimeedu.pohang.go.kr     2         2     2     2            2
# yeyak.suseong.kr             2         2     2     2            2
# www.kira.or.kr               2         2     2     2            2
# lib.yangsan.go.kr            2         2     2     2            2
# lib.happy700.or.kr           2         2     2     2            2
# lib.gwangsan.go.kr           2         2     2     2            2
# juminpoint.bukgu.ulsan.kr    2         2     2     2            2
# jucha.goyang.go.kr           2         2     2     2            2
# jeonbuk.childcare.go.kr      2         2     2     2            2
# ncpms.rda.go.kr              2         2     2     2            2
# www.gosims.go.kr             2         2     2     2            2
# point.gwangsan.go.kr         2         2     2     2            2
# seoul.childcare.go.kr        2         2     2     2            2
# sodac.nier.go.kr             2         2     2     2            2
# www.geap.go.kr               2         2     2     2            2
# traffic.gangnam.go.kr        2         2     2     2            2
# traffic.junggu.seoul.kr      2         2     2     2            2
# traffic.mapo.go.kr           2         2     2     2            2
# ...                        ...       ...   ...   ...          ...
# gdoc.go.kr                   1         1     1     1            1
# etas.ts2020.kr               1         1     1     1            1
# dms.kcg.go.kr                1         1     1     1            1
# dais.karts.ac.kr             1         1     1     1            1
# cne.go.kr                    1         1     1     1            1
# cheongma.or.kr               1         1     1     1            1
# biz.gimhae.go.kr             1         1     1     1            1
# bike.gimhae.go.kr            1         1     1     1            1
# archive.cncae.go.kr          1         1     1     1            1
# minwon.kma.go.kr             1         1     1     1            1
# minwon.nps.or.kr             1         1     1     1            1
# museum.navy.ac.kr            1         1     1     1            1
# welfare.navy.mil.kr          1         1     1     1            1
# www.cnased.go.kr             1         1     1     1            1
# www.cle.or.kr                1         1     1     1            1
# www.cifle.go.kr              1         1     1     1            1
# www.budamgum.or.kr           1         1     1     1            1
# www.bppl.or.kr               1         1     1     1            1
# www.barotalk.kr              1         1     1     1            1
# wems.nier.go.kr              1         1     1     1            1
# value.fact.or.kr             1         1     1     1            1
# real.shlib.or.kr             1         1     1     1            1
# tour.gimje.go.kr             1         1     1     1            1
# tia.molit.go.kr              1         1     1     1            1
# anypay.nps.or.kr             1         1     1     1            1
# special.cngje.go.kr          1         1     1     1            1
# sp.cnased.go.kr              1         1     1     1            1
# satp.goe.go.kr               1         1     1     1            1
# saeil.mogef.go.kr            1         1     1     1            1
# sti.kostat.go.kr             1         1     1     1            1
#
# [125 rows x 5 columns]

# %%
grp_in_exe
# Out:
#                         url  exe_file  path
# domain
# mail.edunavi.kr:443       2         2     2
# www.ktcu.or.kr            2         2     2
# www.namis.or.kr           2         2     2
# www.ongjin.go.kr          2         2     2
# cals.icpa.or.kr           1         1     1
# edu.gg.go.kr              1         1     1
# etax.busan.go.kr          1         1     1
# sso.jnei.go.kr            1         1     1
# www.e-hipassplus.co.kr    1         1     1
# www.hs-support.go.kr      1         1     1
# www.yeonsu.go.kr          1         1     1

# %%
grp_ext_ax
# Out:
#                             url  ax_file  path
# domain
# www.gov.kr                    6        6     6
# www.gyo6.net                  4        4     4
# hanoischool.net               3        3     3
# buyeosaeil.kr                 3        3     3
# www.hanoischool.net           3        3     3
# www.mpki.go.kr                3        3     3
# land.kwater.or.kr             2        2     2
# gyeongnam.childcare.go.kr     2        2     2
# www.kops.or.kr                2        2     2
# japanese.bukgu.ulsan.kr       2        2     2
# jeju.childcare.go.kr          2        2     2
# jeonbuk.childcare.go.kr       2        2     2
# www.pedsis.co.kr              2        2     2
# kcti.re.kr                    2        2     2
# www.kcti.re.kr                2        2     2
# www.cros.or.kr                2        2     2
# welfare.kcomwel.or.kr         2        2     2
# gyeongbuk.childcare.go.kr     2        2     2
# minwon.nps.or.kr              2        2     2
# www.kwmc.or.kr                2        2     2
# www.kkfs.org                  2        2     2
# total.kcomwel.or.kr           2        2     2
# www.kokran.es.kr              2        2     2
# gyeonggi.childcare.go.kr      2        2     2
# seoul.childcare.go.kr         2        2     2
# www.exportcenter.go.kr        2        2     2
# chungnam.childcare.go.kr      2        2     2
# www.efine.go.kr               2        2     2
# gogo.sen.go.kr                2        2     2
# chungbuk.childcare.go.kr      2        2     2
# ...                         ...      ...   ...
# bike.suncheon.go.kr           1        1     1
# archives.hangeul.go.kr        1        1     1
# order.seed.go.kr              1        1     1
# pureunsum.gwd.go.kr           1        1     1
# www.gpdaeya.es.kr             1        1     1
# road.jeonnam.go.kr            1        1     1
# www.fplove.or.kr              1        1     1
# www.forest.go.kr              1        1     1
# www.dsl.daegu.kr              1        1     1
# www.dojang.es.kr              1        1     1
# www.dhc.ac.kr                 1        1     1
# www.deokjang.ms.kr            1        1     1
# www.dalseoij.org              1        1     1
# www.bgja.ms.kr                1        1     1
# archive.history.go.kr         1        1     1
# wdoc.snuh.org                 1        1     1
# value.fact.or.kr              1        1     1
# utis.changwon.go.kr           1        1     1
# u119.nema.go.kr               1        1     1
# traffic.gccity.go.kr          1        1     1
# toursacheon.net               1        1     1
# theater.arko.or.kr            1        1     1
# sodac.nier.go.kr              1        1     1
# sll.seoul.go.kr               1        1     1
# sjw.history.go.kr             1        1     1
# sillok.history.go.kr          1        1     1
# seobu-market.gwangju.go.kr    1        1     1
# sejongstory.or.kr             1        1     1
# seis.or.kr                    1        1     1
# ydespecial.kr                 1        1     1
#
# [139 rows x 3 columns]

# %%
grp_in_ax
# Out:
#                        url  ax_file  path
# domain
# g-money.gg.go.kr         2        2     2
# minwon.nps.or.kr         2        2     2
# ebid.knoc.co.kr          1        1     1
# www.gangjinsports.com    1        1     1
# www.gochang.go.kr        1        1     1
# www.jntv.go.kr           1        1     1
# www.ksmc.or.kr           1        1     1

# %%
df_ext_exe_expanded.groupby('exe_file').agg('count').sort_values('url', ascending=False)
# Out:
#                                                     url
# exe_file
# KCaseAgent_Installer.exe                             17
# xwcup_install_windows_x86.exe                        16
# xwcup_install_windows_x64.exe                        16
# GPKISecureWebX.exe                                   14
# TouchEn_nxKey_Installer_32bit.exe                    12
# TouchEn_nxKey_Installer_64bit.exe                    12
# GPKISecureWebXPlugin.exe                              8
# GPKISecureWebXPlugin64.exe                            8
# wmpfirefoxplugin.exe                                  7
# jre-1_5_0_11-windows-i586-p-s.exe                     5
# Viewer.exe                                            5
# xw_install.exe                                        4
# Printmade2_setup.exe                                  4
# keysharpbiz.exe                                       3
# jre-1_5_0_22-windows-i586-p.exe                       3
# keysharpbiz-x64.exe                                   3
# install_off_v1.0.4.9.exe                              2
# jre-6u25-windows-i586.exe                             2
# SecuKitNXS.exe                                        2
# keysharpnxbiz.exe                                     2
# SecuXML.exe                                           2
# .test(pinfo.exe                                       2
# INIS60.exe                                            2
# KCaseAgent_Installer_v1.3.13.exe                      2
# KMS.exe                                               2
# KCaseAgent_Installer_v1.3.6.exe                       2
# SKCertServiceSetup_v2.4.5_61.exe                      1
# story_earth.exe                                       1
# KSignClient_v1.3.9.exe                                1
# KSbiz_Installer_64bit.exe                             1
# ...                                                 ...
# story_san.exe                                         1
# story_yellow.exe                                      1
# veraport-g3-sha2.exe                                  1
# veraport-g3-x64-sha2.exe                              1
# veraport-g3-x64.exe                                   1
# veraport-g3.exe                                       1
# ChromeStandaloneSetup64.exe                           1
# MAWS_KWaterOz_Setup.exe                               1
# installCheck.jsp")}else{}if(maOnlyInstallFlag==...    1
# hConvert2pfx.exe                                      1
# TouchEnkey_Installer_3108_32bit_multikill.exe         1
# SisunGIS.exe                                          1
# TouchEnKey_Installer3.1.0.16_32bit_allkill.exe        1
# TouchEnKey_Installer_3.1.0.16_32bit_multikill.exe     1
# TouchEnKey_Installer_3.1.0.16_64bit_multikill.exe     1
# TouchEnKey_Installer_32bit_3.1.0.34_multikill.exe     1
# SKCertServiceSetup_v2.0.11_r2325.exe                  1
# SCSKVXULInst.exe                                      1
# TouchEnkey_Installer_3104.exe                         1
# ChromeStandaloneSetup.exe                             1
# flashplayer11_9r900_170_winax.exe                     1
# Printmade3_setup.exe                                  1
# WebCubeAgentSetup.exe                                 1
# XPLATFORM9.2_Setup.exe                                1
# XPLATFORM9.2_SetupEngine.exe                          1
# XPLATFORM9.2_XPLauncher.exe                           1
# ^(([a-zA-Z]:)|(\\{2}\w+)\$?)(\\(\w[\w].*))+(.js...    1
# ^.*\.exe                                              1
# ewsinstaller_full.exe                                 1
# TouchEnweb_Installer.exe                              1
#
# [66 rows x 1 columns]

# %%
df_in_exe_expanded.groupby('exe_file').agg('count').sort_values('url', ascending=False)
# Out:
#                                        url
# exe_file
# astx_setup.exe                           4
# GPKISecureWebX.exe                       2
# CX60_Plugin_u_setup.exe                  1
# CX60u_OCX_setup.exe                      1
# HTML5v1.3.7.exe                          1
# ISignPlusWA_Setup_3.0.13.1.exe           1
# JXCealNT.exe                             1
# JXCealPlugin.exe                         1
# MiPlatform_SetupDeploy320U_200907.exe    1
# PrintPluginSetup.exe                     1
# VestCertSetup.exe                        1

# %%
external.loc[idx_ext_ax, cols_file]
# Out:
#                                                     url  \
# 0     http://www.kops.or.kr/AnySign/anySign4PCInterf...
# 17    http://gangwon.childcare.go.kr/html/Xecure/xec...
# 45    http://sll.seoul.go.kr/js/framework/ui/clipboa...
# 70    http://council.chilgok.go.kr/public/java/desig...
# 72       http://library.chilgok.go.kr/./js/newCommon.js
# 80               http://ydespecial.kr/./js/newCommon.js
# 86                http://lib.cd.go.kr/./js/newCommon.js
# 97              http://lib.jp.go.kr/./jslib/path_fun.js
# 104                http://wdoc.snuh.org/login/cqweb.inc
# 113     http://traffic.gccity.go.kr/js/common/common.js
# 139         http://gdoc.go.kr/gpki/gpkisecureweb/var.js
# 144        http://cont.kisa.or.kr/nxbiz/nxbiz_config.js
# 168           http://japanese.bukgu.ulsan.kr/flash-1.js
# 169             http://japanese.bukgu.ulsan.kr/flash.js
# 180         http://www.dalseoij.org/./jslib/path_fun.js
# 227          http://lib.yeongju.go.kr/./js/newCommon.js
# 371       http://market.jeongeup.go.kr/common/common.js
# 405    http://food.sen.go.kr/MagicLine4/js/MagicLine.js
# 406   http://www.namdokorea.com/kr2/common/js/AC_Run...
# 411   http://utis.changwon.go.kr/resources/js/traffi...
# 448   http://gyeonggi.childcare.go.kr/html/Xecure/xe...
# 459        http://pureunsum.gwd.go.kr/page/js/common.js
# 471   http://www.kaist.edu/js/clipboard/ZeroClipboar...
# 478   http://www.knpgun.go.kr/initech/plugin/install.js
# 507            http://cals.icpa.or.kr/install/Mi_ocx.js
# 512         http://www.kgs.or.kr/kgsmain/flash/flash.js
# 515          http://cpoint.or.kr/markany/markanyload.js
# 521   http://www.pedsis.co.kr/resources/xecure/xecur...
# 527           http://sejongstory.or.kr/inc/js/design.js
# 528         http://seis.or.kr/IssacWeb/js/IssacWebAx.js
# ...                                                 ...
# 4719  http://chungbuk.childcare.go.kr/html/Xecure/xe...
# 4724  http://jeonbuk.childcare.go.kr/html/Xecure/xec...
# 4725  http://gyeongbuk.childcare.go.kr/html/Xecure/x...
# 4726  http://jeju.childcare.go.kr/html/Xecure/xecure...
# 4759           http://biztax.nyj.go.kr/nyj/js/Common.js
# 4760       http://biztax.nyj.go.kr/nyj/js/flashWrite.js
# 4761         http://www.scmarket.or.kr/common/common.js
# 4762  http://e-bid.kari.re.kr/hsecure/anySign4PCInte...
# 4772  http://toursacheon.net/common/js/xe.min.js?201...
# 4774  http://www.mwyouth.org/common/js/xe.min.js?201...
# 4775  http://mwyouth.org/common/js/xe.min.js?2014100...
# 4778  http://consumer.gwd.go.kr/addons/captcha_membe...
# 4786                 http://www.ktc.ac.kr/_css/flash.js
# 4788  http://www.kkfs.org/xe/common/js/xe.min.js?201...
# 4789  http://www.kkfs.org/xe/addons/captcha/captcha....
# 4790  http://www.wonbuddhism.ac.kr/common/js/xe.min....
# 4791  http://wonbuddhism.ac.kr/common/js/xe.min.js?2...
# 4792  http://www.kis.ac/common/js/xe.min.js?20180307...
# 4795  http://www.kumho-art.com/xe/common/js/xe.min.j...
# 4800  http://hanoischool.net/common/js/xe.min.js?201...
# 4801  http://hanoischool.net/addons/captcha_member/c...
# 4802  http://hanoischool.net/addons/captcha/captcha....
# 4803  http://www.hanoischool.net/common/js/xe.min.js...
# 4804  http://www.hanoischool.net/addons/captcha_memb...
# 4805  http://www.hanoischool.net/addons/captcha/capt...
# 4806  http://www.hotline.or.kr/common/js/xe.min.js?2...
# 4813  http://www.ienet.re.kr/mediaelementjs/mediaele...
# 4819  http://buyeosaeil.kr/buyeosaeil/common/js/xe.m...
# 4820  http://buyeosaeil.kr/buyeosaeil/addons/captcha...
# 4821  http://buyeosaeil.kr/buyeosaeil/addons/captcha...
#
#                                                 ax_file  \
# 0     [xwcup_install_windows_x86.cab, xwcup_install_...
# 17    [xwcup_install_windows_x64.cab, xwcup_install_...
# 45                                        [swflash.cab]
# 70                                        [swflash.cab]
# 72                                        [swflash.cab]
# 80                                        [swflash.cab]
# 86                                        [swflash.cab]
# 97                                        [swflash.cab]
# 104                                      [TrustWeb.cab]
# 113                                       [swflash.cab]
# 139                                 [GPKIInstaller.cab]
# 144              [keysharpbiz-x64.cab, keysharpbiz.cab]
# 168                                       [swflash.cab]
# 169                                       [swflash.cab]
# 180                                       [swflash.cab]
# 227                                       [swflash.cab]
# 371                                       [swflash.cab]
# 405              [MagicLineMBX.cab, MagicLineMBX64.cab]
# 406                                       [swflash.cab]
# 411                                      [nsmp2inf.cab]
# 448   [xwcup_install_windows_x64.cab, xwcup_install_...
# 459                                       [swflash.cab]
# 471                                       [swflash.cab]
# 478              [INIS60_"+CodeSigningHashName()+".cab]
# 507                                  [MiUpdater331.cab]
# 512                                       [swflash.cab]
# 515                              [MaWebSAFER_STDEP.cab]
# 521   [xwcup_install_windows_x86.cab, xwcup_install_...
# 527                                       [swflash.cab]
# 528                       [IssacWebProCMS_4_5_0_24.cab]
# ...                                                 ...
# 4719  [xwcup_install_windows_x64.cab, xwcup_install_...
# 4724  [xwcup_install_windows_x64.cab, xwcup_install_...
# 4725  [xwcup_install_windows_x64.cab, xwcup_install_...
# 4726  [xwcup_install_windows_x64.cab, xwcup_install_...
# 4759                                   [UbiViewerX.cab]
# 4760                                      [swflash.cab]
# 4761                                      [swflash.cab]
# 4762  [xwcup_install_windows_x86.cab, xwcup_install_...
# 4772                                      [swflash.cab]
# 4774                                      [swflash.cab]
# 4775                                      [swflash.cab]
# 4778                                      [swflash.cab]
# 4786                                      [swflash.cab]
# 4788                                      [swflash.cab]
# 4789                                      [swflash.cab]
# 4790                                      [swflash.cab]
# 4791                                      [swflash.cab]
# 4792                                      [swflash.cab]
# 4795                                      [swflash.cab]
# 4800                                      [swflash.cab]
# 4801                                      [swflash.cab]
# 4802                                      [swflash.cab]
# 4803                                      [swflash.cab]
# 4804                                      [swflash.cab]
# 4805                                      [swflash.cab]
# 4806                                      [swflash.cab]
# 4813                                      [swflash.cab]
# 4819                                      [swflash.cab]
# 4820                                      [swflash.cab]
# 4821                                      [swflash.cab]
#
#                                                exe_file
# 0     [hConvert2pfx.exe, xwcup_install_windows_x64.e...
# 17    [xwcup_install_windows_x64.exe, xwcup_install_...
# 45                                                   []
# 70                                                   []
# 72                                                   []
# 80                                                   []
# 86                                                   []
# 97                                                   []
# 104                                                  []
# 113                                                  []
# 139                          [install_off_v1.0.4.9.exe]
# 144   [keysharpbiz-x64.exe, keysharpbiz.exe, keyshar...
# 168                                                  []
# 169                                                  []
# 180                                                  []
# 227                                                  []
# 371                                                  []
# 405   [jre-6u25-windows-i586.exe, jre-1_5_0_22-windo...
# 406                                                  []
# 411                                                  []
# 448   [xwcup_install_windows_x64.exe, xwcup_install_...
# 459                                                  []
# 471                                                  []
# 478                                        [INIS60.exe]
# 507                                                  []
# 512                                                  []
# 515                                                  []
# 521   [xwcup_install_windows_x64.exe, xwcup_install_...
# 527                                                  []
# 528                                                  []
# ...                                                 ...
# 4719  [xwcup_install_windows_x64.exe, xwcup_install_...
# 4724  [xwcup_install_windows_x64.exe, xwcup_install_...
# 4725  [xwcup_install_windows_x64.exe, xwcup_install_...
# 4726  [xwcup_install_windows_x64.exe, xwcup_install_...
# 4759                                                 []
# 4760                                                 []
# 4761                                                 []
# 4762  [xwcup_install_windows_x64.exe, xwcup_install_...
# 4772                                                 []
# 4774                                                 []
# 4775                                                 []
# 4778                                                 []
# 4786                                                 []
# 4788                                                 []
# 4789                                                 []
# 4790                                                 []
# 4791                                                 []
# 4792                                                 []
# 4795                                                 []
# 4800                                                 []
# 4801                                                 []
# 4802                                                 []
# 4803                                                 []
# 4804                                                 []
# 4805                                                 []
# 4806                                                 []
# 4813                                                 []
# 4819                                                 []
# 4820                                                 []
# 4821                                                 []
#
# [157 rows x 3 columns]

# %%
external.loc[idx_ext_exe, 'exe_code'].apply(split_list_and_get_file_name)
# Out:
# 0       [hConvert2pfx.exe, xwcup_install_windows_x64.e...
# 17      [xwcup_install_windows_x64.exe, xwcup_install_...
# 28                                 [wmpfirefoxplugin.exe]
# 31                             [install_off_v1.0.4.9.exe]
# 35                     [KCaseAgent_Installer_v1.3.13.exe]
# 36                             [KCaseAgent_Installer.exe]
# 40                     [.test(pinfo.exe, .test(pinfo.exe]
# 55      [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 62      [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 107     [GPKISecureWebXPlugin.exe, GPKISecureWebXPlugi...
# 112     [GPKISecureWebXPlugin.exe, GPKISecureWebXPlugi...
# 118     [GPKISecureWebXPlugin.exe, GPKISecureWebXPlugi...
# 122     [GPKISecureWebXPlugin.exe, GPKISecureWebXPlugi...
# 127     [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 128     [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 129     [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 135                            [KCaseAgent_Installer.exe]
# 139                            [install_off_v1.0.4.9.exe]
# 144     [keysharpbiz-x64.exe, keysharpbiz.exe, keyshar...
# 158                   [jre-1_5_0_11-windows-i586-p-s.exe]
# 181                                [wmpfirefoxplugin.exe]
# 189                    [Printmade2_setup.exe, Viewer.exe]
# 252     [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 271     [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 307                                [wmpfirefoxplugin.exe]
# 316                   [flashplayer11_9r900_170_winax.exe]
# 350                                  [GPKISecureWebX.exe]
# 353                                  [GPKISecureWebX.exe]
# 405     [jre-6u25-windows-i586.exe, jre-1_5_0_22-windo...
# 410     [GPKISecureWebXPlugin.exe, GPKISecureWebXPlugi...
#                               ...
# 3826                           [KCaseAgent_Installer.exe]
# 3911    [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 3914    [TouchEn_nxKey_Installer_64bit.exe, TouchEn_nx...
# 3952                                 [GPKISecureWebX.exe]
# 3967                   [Printmade3_setup.exe, Viewer.exe]
# 3995                           [KCaseAgent_Installer.exe]
# 3999                           [KCaseAgent_Installer.exe]
# 4599    [TouchEnKey_Installer_3.1.0.16_64bit_multikill...
# 4602    [XPLATFORM9.2_Setup.exe, XPLATFORM9.2_XPLaunch...
# 4605    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4640                                 [GPKISecureWebX.exe]
# 4641    [^(([a-zA-Z]:)|(\\{2}\w+)\$?)(\\(\w[\w].*))+(....
# 4647                                     [xw_install.exe]
# 4655                                         [INIS60.exe]
# 4666                              [WebCubeAgentSetup.exe]
# 4668     [TouchEnKey_Installer3.1.0.16_32bit_allkill.exe]
# 4677                                 [GPKISecureWebX.exe]
# 4682               [keysharpbiz-x64.exe, keysharpbiz.exe]
# 4711    [GPKISecureWebXPlugin.exe, GPKISecureWebXPlugi...
# 4714    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4715    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4716    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4717    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4719    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4724    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4725    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4726    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4729    [ChromeStandaloneSetup.exe, ChromeStandaloneSe...
# 4762    [xwcup_install_windows_x64.exe, xwcup_install_...
# 4784    [MAWS_KWaterOz_Setup.exe, installCheck.jsp")}e...
# Name: exe_code, Length: 129, dtype: object

# %%
external.loc[idx_ext_ax, cols]
# Out:
#                                                     url  \
# 0     http://www.kops.or.kr/AnySign/anySign4PCInterf...
# 17    http://gangwon.childcare.go.kr/html/Xecure/xec...
# 45    http://sll.seoul.go.kr/js/framework/ui/clipboa...
# 70    http://council.chilgok.go.kr/public/java/desig...
# 72       http://library.chilgok.go.kr/./js/newCommon.js
# 80               http://ydespecial.kr/./js/newCommon.js
# 86                http://lib.cd.go.kr/./js/newCommon.js
# 97              http://lib.jp.go.kr/./jslib/path_fun.js
# 104                http://wdoc.snuh.org/login/cqweb.inc
# 113     http://traffic.gccity.go.kr/js/common/common.js
# 139         http://gdoc.go.kr/gpki/gpkisecureweb/var.js
# 144        http://cont.kisa.or.kr/nxbiz/nxbiz_config.js
# 168           http://japanese.bukgu.ulsan.kr/flash-1.js
# 169             http://japanese.bukgu.ulsan.kr/flash.js
# 180         http://www.dalseoij.org/./jslib/path_fun.js
# 227          http://lib.yeongju.go.kr/./js/newCommon.js
# 371       http://market.jeongeup.go.kr/common/common.js
# 405    http://food.sen.go.kr/MagicLine4/js/MagicLine.js
# 406   http://www.namdokorea.com/kr2/common/js/AC_Run...
# 411   http://utis.changwon.go.kr/resources/js/traffi...
# 448   http://gyeonggi.childcare.go.kr/html/Xecure/xe...
# 459        http://pureunsum.gwd.go.kr/page/js/common.js
# 471   http://www.kaist.edu/js/clipboard/ZeroClipboar...
# 478   http://www.knpgun.go.kr/initech/plugin/install.js
# 507            http://cals.icpa.or.kr/install/Mi_ocx.js
# 512         http://www.kgs.or.kr/kgsmain/flash/flash.js
# 515          http://cpoint.or.kr/markany/markanyload.js
# 521   http://www.pedsis.co.kr/resources/xecure/xecur...
# 527           http://sejongstory.or.kr/inc/js/design.js
# 528         http://seis.or.kr/IssacWeb/js/IssacWebAx.js
# ...                                                 ...
# 4719  http://chungbuk.childcare.go.kr/html/Xecure/xe...
# 4724  http://jeonbuk.childcare.go.kr/html/Xecure/xec...
# 4725  http://gyeongbuk.childcare.go.kr/html/Xecure/x...
# 4726  http://jeju.childcare.go.kr/html/Xecure/xecure...
# 4759           http://biztax.nyj.go.kr/nyj/js/Common.js
# 4760       http://biztax.nyj.go.kr/nyj/js/flashWrite.js
# 4761         http://www.scmarket.or.kr/common/common.js
# 4762  http://e-bid.kari.re.kr/hsecure/anySign4PCInte...
# 4772  http://toursacheon.net/common/js/xe.min.js?201...
# 4774  http://www.mwyouth.org/common/js/xe.min.js?201...
# 4775  http://mwyouth.org/common/js/xe.min.js?2014100...
# 4778  http://consumer.gwd.go.kr/addons/captcha_membe...
# 4786                 http://www.ktc.ac.kr/_css/flash.js
# 4788  http://www.kkfs.org/xe/common/js/xe.min.js?201...
# 4789  http://www.kkfs.org/xe/addons/captcha/captcha....
# 4790  http://www.wonbuddhism.ac.kr/common/js/xe.min....
# 4791  http://wonbuddhism.ac.kr/common/js/xe.min.js?2...
# 4792  http://www.kis.ac/common/js/xe.min.js?20180307...
# 4795  http://www.kumho-art.com/xe/common/js/xe.min.j...
# 4800  http://hanoischool.net/common/js/xe.min.js?201...
# 4801  http://hanoischool.net/addons/captcha_member/c...
# 4802  http://hanoischool.net/addons/captcha/captcha....
# 4803  http://www.hanoischool.net/common/js/xe.min.js...
# 4804  http://www.hanoischool.net/addons/captcha_memb...
# 4805  http://www.hanoischool.net/addons/captcha/capt...
# 4806  http://www.hotline.or.kr/common/js/xe.min.js?2...
# 4813  http://www.ienet.re.kr/mediaelementjs/mediaele...
# 4819  http://buyeosaeil.kr/buyeosaeil/common/js/xe.m...
# 4820  http://buyeosaeil.kr/buyeosaeil/addons/captcha...
# 4821  http://buyeosaeil.kr/buyeosaeil/addons/captcha...
#
#                                                 ax_code  \
# 0     [install/xwcup_install_windows_x86.cab, instal...
# 17    [activex/Xecure/xw/xwcup_install_windows_x64.c...
# 45               [pub/shockwave/cabs/flash/swflash.cab]
# 70                                  [flash/swflash.cab]
# 72                                  [flash/swflash.cab]
# 80                                  [flash/swflash.cab]
# 86                                  [flash/swflash.cab]
# 97                                  [flash/swflash.cab]
# 104                                [CQWeb/TrustWeb.cab]
# 113   [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 139        [gpki/gpkisecureweb/setup/GPKIInstaller.cab]
# 144              [keysharpbiz-x64.cab, keysharpbiz.cab]
# 168   [/download.macromedia.com/pub/shockwave/cabs/f...
# 169   [/download.macromedia.com/pub/shockwave/cabs/f...
# 180                                 [flash/swflash.cab]
# 227                                 [flash/swflash.cab]
# 371                           [include/lib/swflash.cab]
# 405              [MagicLineMBX.cab, MagicLineMBX64.cab]
# 406                                [images/swflash.cab]
# 411   [/activex.microsoft.com/activex/controls/mplay...
# 448   [activex/Xecure/xw/xwcup_install_windows_x64.c...
# 459                  [shockwave/cabs/flash/swflash.cab]
# 471              [pub/shockwave/cabs/flash/swflash.cab]
# 478              [INIS60_"+CodeSigningHashName()+".cab]
# 507                      [install/330/MiUpdater331.cab]
# 512   [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 515                              [MaWebSAFER_STDEP.cab]
# 521   [resources/xecure/install/xwcup_install_window...
# 527   [/download.macromedia.com/pub/shockwave/cabs/f...
# 528          [IssacWeb/cab/IssacWebProCMS_4_5_0_24.cab]
# ...                                                 ...
# 4719  [activex/Xecure/xw/xwcup_install_windows_x64.c...
# 4724  [activex/Xecure/xw/xwcup_install_windows_x64.c...
# 4725  [activex/Xecure/xw/xwcup_install_windows_x64.c...
# 4726  [activex/Xecure/xw/xwcup_install_windows_x64.c...
# 4759                         [ubiviewer/UbiViewerX.cab]
# 4760  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4761                          [include/lib/swflash.cab]
# 4762  [install/xwcup_install_windows_x86.cab, instal...
# 4772  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4774  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4775  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4778  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4786                 [shockwave/cabs/flash/swflash.cab]
# 4788  [>'}else{if(/\.swf/i.test(a)){g="clsid:D27CDB6...
# 4789  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4790  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4791  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4792  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4795  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4800  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4801  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4802  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4803  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4804  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4805  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4806  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4813  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4819  [/download.macromedia.com/pub/shockwave/cabs/f...
# 4820  [/fpdownload.macromedia.com/pub/shockwave/cabs...
# 4821  [/fpdownload.macromedia.com/pub/shockwave/cabs...
#
#                                                exe_code
# 0     [download/hConvert2pfx.exe, install/xwcup_inst...
# 17    [activex/Xecure/xw/xwcup_install_windows_x64.e...
# 45                                                   []
# 70                                                   []
# 72                                                   []
# 80                                                   []
# 86                                                   []
# 97                                                   []
# 104                                                  []
# 113                                                  []
# 139   [gpki/gpkisecureweb/setup/install_off_v1.0.4.9...
# 144   [keysharpbiz-x64.exe, keysharpbiz.exe, keyshar...
# 168                                                  []
# 169                                                  []
# 180                                                  []
# 227                                                  []
# 371                                                  []
# 405   [jre-6u25-windows-i586.exe, jre-1_5_0_22-windo...
# 406                                                  []
# 411                                                  []
# 448   [activex/Xecure/xw/xwcup_install_windows_x64.e...
# 459                                                  []
# 471                                                  []
# 478                                        [INIS60.exe]
# 507                                                  []
# 512                                                  []
# 515                                                  []
# 521   [resources/xecure/install/xwcup_install_window...
# 527                                                  []
# 528                                                  []
# ...                                                 ...
# 4719  [activex/Xecure/xw/xwcup_install_windows_x64.e...
# 4724  [activex/Xecure/xw/xwcup_install_windows_x64.e...
# 4725  [activex/Xecure/xw/xwcup_install_windows_x64.e...
# 4726  [activex/Xecure/xw/xwcup_install_windows_x64.e...
# 4759                                                 []
# 4760                                                 []
# 4761                                                 []
# 4762  [install/xwcup_install_windows_x64.exe, instal...
# 4772                                                 []
# 4774                                                 []
# 4775                                                 []
# 4778                                                 []
# 4786                                                 []
# 4788                                                 []
# 4789                                                 []
# 4790                                                 []
# 4791                                                 []
# 4792                                                 []
# 4795                                                 []
# 4800                                                 []
# 4801                                                 []
# 4802                                                 []
# 4803                                                 []
# 4804                                                 []
# 4805                                                 []
# 4806                                                 []
# 4813                                                 []
# 4819                                                 []
# 4820                                                 []
# 4821                                                 []
#
# [157 rows x 3 columns]

# %%
in_page.loc[::, cols].head()
# Out:
#                                                  url ax_code exe_code
# 0                 http://www.butterflyhp.or.kr/main/      []       []
# 1  http://butterflyhp.or.kr/application/member/lo...      []       []
# 2  http://www.butterflyhp.or.kr/application/membe...      []       []
# 3               http://own.kribb.re.kr/main/main.jsp      []       []
# 4               http://edu.kribb.re.kr/main/main.jsp      []       []

# %%
external.loc[::, cols]. head()
# Out:
#                                                  url  \
# 0  http://www.kops.or.kr/AnySign/anySign4PCInterf...
# 1         http://www.gwangju.go.kr/home/js/global.js
# 2           http://michu.incheon.kr/share/js/base.js
# 3    http://michu.incheon.kr/share/js/base_subong.js
# 4            http://michu.incheon.kr/ShareEtc/chk.js
#
#                                              ax_code  \
# 0  [install/xwcup_install_windows_x86.cab, instal...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                             exe_code
# 0  [download/hConvert2pfx.exe, install/xwcup_inst...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []

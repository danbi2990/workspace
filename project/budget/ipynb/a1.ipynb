# %% [markdown]
# # Import

# %%
from collections import defaultdict
from collections import Counter
from pprint import pprint

from konlpy.tag import Mecab, Kkma
import pandas as pd

# %% [markdown]
# # Load

# %%
directory = '/home/jake/Documents/'
file_2019 = '2019년_경제정책방향.txt'

file_2018 = '2018년_경제정책방향.txt'

with open(directory + file_2019, 'r') as f:
    raw_2019 = f.read()

with open(directory + file_2018, 'r') as f:
    raw_2018 = f.read()

# %%
"""
NNG 일반 명사
NNP 고유 명사
NNB 의존 명사
NNBC    단위를 나타내는 명사
NR  수사
NP  대명사

VV  동사

VA  형용사
VX  보조 용언
VCP 긍정 지정사
VCN 부정 지정사

MM  관형사
MAG 일반 부사
MAJ 접속 부사
"""
tags = ['NNG', 'NNP', 'NNB', 'NNBC', 'NR', 'NP', 'VV', 'VA', 'VX', 'VCP', 'VCN', 'MM', 'MAG', 'MAJ', 'IC', 'JKS', 'JKC', 'JKG', 'JKO',
        'JKB', 'JKV', 'JKQ', 'JC', 'JX', 'EP', 'EF', 'EC', 'ETN', 'ETM', 'XPN', 'XSN', 'XSV', 'XSA', 'XR', 'SF', 'SE', 'SSO', 'SSC',
        'SC', 'SY', 'SH', 'SL', 'SN',]

# %% [markdown]
# # Globals

# %%
mecab = Mecab()

# %% [markdown]
# # 2019 형태소 분석: counters_2019

# %%
list_of_pos_2019 = mecab.pos(raw_2019)
dict_of_pos_2019 = defaultdict(list)

for p in list_of_pos_2019:
    dict_of_pos_2019[p[1]].append(p[0])

counters_2019 = {}

for tag, words in dict_of_pos_2019.items():
    cnter = Counter(words)
    counters_2019[tag] = cnter

# %% [markdown]
# # 2018 형태소 분석: counters_2018

# %%
list_of_pos_2018 = mecab.pos(raw_2018)
dict_of_pos_2018 = defaultdict(list)

for p in list_of_pos_2018:
    dict_of_pos_2018[p[1]].append(p[0])

counters_2018 = {}

for tag, words in dict_of_pos_2018.items():
    cnter = Counter(words)
    counters_2018[tag] = cnter

# %% [markdown]
# # Functions

# %%
# pprint(counters_2019['NNG'].most_common(20))


def get_ranking_chart_table(tag, counter_2019, counter_2018):
    tmp = [list(t) for t in counter_2019.most_common()]
    [t.append('2019') for t in tmp]

    tmp2 = [list(t) for t in counter_2018.most_common()]
    [t.append('2018') for t in tmp2]
  
    df = pd.DataFrame(columns=[f'{tag}_word', 'count', 'year'], data=tmp)
    df_2018 = pd.DataFrame(columns=[f'{tag}_word', 'count', 'year'], data=tmp2)
    df = df.append(df_2018)

    df.index = df.index+1
    return df


def get_word_cloud_table(tag, counter_2019, counter_2018):
    df = pd.DataFrame(columns=[f'{tag}_word', '2019'], data=counter_2019.most_common())
    df_2018 = pd.DataFrame(columns=[f'{tag}_word', '2018'], data=counter_2018.most_common())
    df = df_2018.merge(df, on=f'{tag}_word', how='outer')

    df = pd.DataFrame(columns=[f'2019_{tag}_word', f'2019_{tag}_count'], data=counter_2019.most_common())
    df_2018 = pd.DataFrame(columns=[f'2018_{tag}_word', f'2018_{tag}_count'], data=counter_2018.most_common())
    df = df_2018.merge(df, left_index=True, right_index=True, how='outer')
    
    df.index.name = '순위'
    df.index = df.index+1
    return df

# %% [markdown]
# # Creating Tables

# %%
word_cloud_table = {}
ranking_chart_table = {}

for tag in tags:
    counter_2019 = counters_2019.get(tag, Counter())
    counter_2018 = counters_2018.get(tag, Counter())
    word_cloud_table[tag] = get_word_cloud_table(tag, counter_2019, counter_2018)
    ranking_chart_table[tag] = get_ranking_chart_table(tag, counter_2019, counter_2018)

# %% [markdown]
# # ---

# %% [markdown]
# # Word Cloud

# %%
# comparison_table['NNP'].head(25).to_csv('', sep='\t')

tag = 'NNP'

word_cloud_table[tag].head(25)
# Out:
#    2018_NNP_word  2018_NNP_count 2019_NNP_word  2019_NNP_count
# 순위
# 1           한국은행            23.0          한국은행              21
# 2             한국            21.0            중국              15
# 3             중국            14.0            미국              14
# 4            저출산            13.0            물류              14
# 5           거시경제            12.0          최저임금              11
# 6             일본            11.0           고용부              11
# 7             평창            11.0           바이오              10
# 8            고용부            10.0           저출산               9
# 9            스마트            10.0            남북               9
# 10          균형발전            10.0            한국               9
# 11           로드맵             9.0            서울               8
# 12           올림픽             9.0            일본               6
# 13            미국             8.0           크루즈               6
# 14          최저임금             8.0            인도               6
# 15             팜             8.0           아세안               6
# 16           연기금             8.0            조선               6
# 17            조선             7.0            기저               6
# 18           공정위             6.0          균형발전               5
# 19          채무조정             6.0          정책금융               5
# 20            매칭             5.0            공유               5
# 21           아세안             5.0          거시경제               4
# 22            드론             5.0          미세먼지               4
# 23            서울             5.0            강화               4
# 24            물류             5.0            강원               4
# 25        기업지배구조             5.0            행안               4

# %% [markdown]
# # ---

# %% [markdown]
# # Ranking Chart

# %% [markdown]
# ## 일반명사

# %%
'''
2018년 톱15 + 2019년 톱10 단어를 뽑을 예정
'''
tag = 'NNG'
x = 10
y = 15

top_x_2019 = list(zip(*counters_2019[tag].most_common(x)))[0]
top_y_2018 = list(zip(*counters_2018[tag].most_common(y)))[0]

print(top_y_2018)

idx_2019 = ranking_chart_table[tag]['year'] == '2019'
idx_top_x_2019 = ranking_chart_table[tag][f'{tag}_word'].isin(top_x_2019)
idx_2018 = ranking_chart_table[tag]['year'] == '2018'
idx_top_y_2018 = ranking_chart_table[tag][f'{tag}_word'].isin(top_y_2018)

ranking_chart = ranking_chart_table[tag].loc[(idx_2019 & idx_top_x_2019) | (idx_2018 & idx_top_y_2018)]; ranking_chart

# ranking_chart.to_csv('nng_ranking_chart.tsv', sep='\t', index=False)
# Out:
# ('지원', '확대', '기업', '경제', '혁신', '투자', '추진', '개선', '강화', '금융', '증가', '산업', '정책', '마련', '사업')
#    NNG_word  count  year
# 1        지원    253  2019
# 2        확대    195  2019
# 3        투자    163  2019
# 4        기업    130  2019
# 5        추진    129  2019
# 6        경제    118  2019
# 7        사업    104  2019
# 8        산업     87  2019
# 9        전망     80  2019
# 10       강화     80  2019
# 1        지원    232  2018
# 2        확대    184  2018
# 3        기업    141  2018
# 4        경제    127  2018
# 5        혁신    127  2018
# 6        투자    122  2018
# 7        추진    119  2018
# 8        개선    110  2018
# 9        강화    104  2018
# 10       금융    101  2018
# 11       증가     97  2018
# 12       산업     95  2018
# 13       정책     93  2018
# 14       마련     91  2018
# 15       사업     84  2018

# %% [markdown]
# ## 고유명사

# %%
'''
2018년 톱15 + 2019년 톱10 단어를 뽑을 예정
'''
tag = 'NNP'
x = 10
y = 15

top_x_2019 = list(zip(*counters_2019[tag].most_common(x)))[0]
top_y_2018 = list(zip(*counters_2018[tag].most_common(y)))[0]

nnp_2019 = ['한국은행', '중국', '미국', '고용부', '남북', '한국', '서울', '일본', '인도', '아세안',]
nnp_2018 = ['한국은행', '한국', '중국', '일본', '평창', '고용부', '미국', '공정위', '아세안', '서울',]

print(top_y_2018)

idx_2019 = ranking_chart_table[tag]['year'] == '2019'
# idx_top_x_2019 = ranking_chart_table[tag][f'{tag}_word'].isin(top_x_2019)
idx_top_x_2019 = ranking_chart_table[tag][f'{tag}_word'].isin(nnp_2019)
idx_2018 = ranking_chart_table[tag]['year'] == '2018'
# idx_top_y_2018 = ranking_chart_table[tag][f'{tag}_word'].isin(top_x_2018)
idx_top_y_2018 = ranking_chart_table[tag][f'{tag}_word'].isin(nnp_2018)

ranking_chart = ranking_chart_table[tag].loc[(idx_2019 & idx_top_x_2019) | (idx_2018 & idx_top_y_2018)]; ranking_chart

# ranking_chart.to_csv('nnp_ranking_chart.tsv', sep='\t', index=False)
# Out:
# ('한국은행', '한국', '중국', '저출산', '거시경제', '일본', '평창', '고용부', '스마트', '균형발전', '로드맵', '올림픽', '미국', '최저임금', '팜')
#    NNP_word  count  year
# 1      한국은행     21  2019
# 2        중국     15  2019
# 3        미국     14  2019
# 6       고용부     11  2019
# 9        남북      9  2019
# 10       한국      9  2019
# 11       서울      8  2019
# 12       일본      6  2019
# 14       인도      6  2019
# 15      아세안      6  2019
# 1      한국은행     23  2018
# 2        한국     21  2018
# 3        중국     14  2018
# 6        일본     11  2018
# 7        평창     11  2018
# 8       고용부     10  2018
# 13       미국      8  2018
# 18      공정위      6  2018
# 21      아세안      5  2018
# 23       서울      5  2018

# %% [markdown]
# # ---

# %% [markdown]
# # Setence Chart

# %%
tag = 'NNP'
x = 10

sentences_2019 = raw_2019.split('\n')

sentences_2018 = raw_2018.split('\n')

top_10_2019 = tuple(zip(*counters_2019[tag].most_common(x)))[0]; top_10_2019

nnp_2019 = ['한국은행', '중국', '미국', '고용부', '남북', '한국', '서울', '일본', '인도', '아세안',]

key_sentence_list_2019 = []

for keyword in nnp_2019:
    for sentence in sentences_2019:
        if (keyword in sentence) and not (keyword == '한국' and '한국은행' in sentence):
            key_sentence_list_2019.append(('2019', keyword, sentence.strip()))


top_10_2018 = tuple(zip(*counters_2018[tag].most_common(x)))[0]; top_10_2018

nnp_2018 = ['한국은행', '한국', '중국', '일본', '평창', '고용부', '미국', '공정위', '아세안', '서울',]

key_sentence_list_2018 = []

for keyword in nnp_2018:
    for sentence in sentences_2018:
        if (keyword in sentence) and not (keyword == '한국' and '한국은행' in sentence):
            key_sentence_list_2018.append(('2018', keyword, sentence.strip()))


df_key_sentence_2019 = pd.DataFrame(columns=['연도', '단어', '문장'], data=key_sentence_list_2019); df_key_sentence_2019
df_key_sentence_2018 = pd.DataFrame(columns=['연도', '단어', '문장'], data=key_sentence_list_2018); df_key_sentence_2018

df_key_sentence = df_key_sentence_2019.append(df_key_sentence_2018); df_key_sentence

pd.set_option('display.max_rows', None)
df_key_sentence

# df_key_sentence.to_csv('nnp_sentence.tsv', sep='\t', index=False)
# Out:
#        연도    단어                                                 문장
# 0    2019  한국은행                                   * 자료 : 한국은행, 통계청
# 1    2019  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 2    2019  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 3    2019  한국은행                             * 출처 : 한국은행 * 출처 : 통계청
# 4    2019  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 5    2019  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 6    2019  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 7    2019  한국은행                         * 출처: 관세청, 한국은행 * 출처: 무역협회
# 8    2019  한국은행  * 자료 : 한국은행 ** ‘18~’19년은 정부전망 * 자료 : DRAM Exch...
# 9    2019  한국은행                * 출처 : 통계청, 한국은행, 고용노동부 * 자료 : 한국은행
# 10   2019  한국은행               * 자료 : 한국은행 * 자료 : 문화체육관광부, 법무부, 관세청
# 11   2019  한국은행                        * 출처 : 한국은행, 통계청 * 출처 : 통계청
# 12   2019  한국은행  * 출처 : 과학기술정보통신부, 기획재정부, 한국은행 * 출처 : 통계청, 고용노동...
# 13   2019  한국은행                 * 출처 : 한국은행, 통계청 * 출처 : 소프트웨어정책연구소
# 14   2019  한국은행                               * 출처: 한국은행 * 출처: 통계청
# 15   2019    중국  ➊ 세계경제는 완만한 성장세가 유지되나, 중국.미국.일본 등 우리경제와 밀접한 주요...
# 16   2019    중국                       ‣ 글로벌 반도체 수요와 중국 등의 추격에 선제대응
# 17   2019    중국         * 現 단체비자 허용 국가 : 베트남, 중국, 필리핀, 인도네시아, 캄보디아
# 18   2019    중국                 ▪ 중국.일본 등 주요 한국 방문국가를 대상으로 현지스타 등을
# 19   2019    중국  ▪지역별로는 중국.일본.EU.아세안.미국 등 대부분 지역에 대해 수출이 증가하였으나...
# 20   2019    중국  * 지역별 수출(‘17.1~11→ 18.1~11, 전년비, %): (중국)17.2 ...
# 21   2019    중국  ▪ 중국은 디레버리징 정책으로 인한 투자 감소 및 무역분쟁 영향 등으로 성장세 점차...
# 22   2019    중국  ᄋ 중국은 기업부채와 그림자 금융 등 리스크 요인이 상존하는 가운데, 통상분쟁 심화...
# 23   2019    중국  ᄋ ‘19년 국제유가는 미국 등의 생산증가 및 중국 등 경기둔화에 따른 수요 증가폭...
# 24   2019    중국  * ’18·19년 엘니뇨 발생(‘17·18년 미발생) 확률이 70% 정도로 추정(美...
# 25   2019    중국  ᄋ (기타) 향후 대외리스크 확대 가능성 등은 소비심리 제약요인으로 작용, 다만, ...
# 26   2019    중국                           소비자심리지수 추이 중국인 방한 관광객 추이
# 27   2019    중국                                           중국인방한관광객
# 28   2019    중국  ᄋ (투자여건) 美 금리인상, 보호무역주의 강화, 중국성장 둔화 등 불확실성이 확대...
# 29   2019    중국              (기타) 중국인 관광객 회복속도, 자영업 과당경쟁 등도 영향 요인
# 30   2019    중국  ▪ (지역별) 미국.중국 등 주요국 경기둔화, 국제유가 하락 등으로 미국.중국.중동...
# 31   2019    중국  * 성장률 전망(‘18→’19, IMF): (미국) 2.9 → 2.5 (중국) 6....
# 32   2019    미국               포용적 성장론 확산, 미국, 일본 등 주요국도 관련 정책 시행 중
# 33   2019    미국  ➊ 세계경제는 완만한 성장세가 유지되나, 중국.미국.일본 등 우리경제와 밀접한 주요...
# 34   2019    미국     * 미국경제 및 소비자 기여, 한미 FTA 개정을 통한 호혜여건 기 조성 등을 설명
# 35   2019    미국  ▪지역별로는 중국.일본.EU.아세안.미국 등 대부분 지역에 대해 수출이 증가하였으나...
# 36   2019    미국  * 지역별 수출(‘17.1~11→ 18.1~11, 전년비, %): (중국)17.2 ...
# 37   2019    미국  ▪ 미국은 올해 양호한 성장세를 지속하겠으나, 감세효과 약화, 통상분쟁 영향 본격화...
# 38   2019    미국  ᄋ 미국의 지속적인 금리인상이 예상되는 가운데, 이에 따른 글로벌 금융여건 악화 및...
# 39   2019    미국  ᄋ ‘19년 국제유가는 미국 등의 생산증가 및 중국 등 경기둔화에 따른 수요 증가폭...
# 40   2019    미국  * 미국 원유생산 전망(EIA 12월, 백만배럴/일): (18.상)10.4 (하)1...
# 41   2019    미국                                          80 미국 신흥국
# 42   2019    미국  ▪ (지역별) 미국.중국 등 주요국 경기둔화, 국제유가 하락 등으로 미국.중국.중동...
# 43   2019    미국  * 성장률 전망(‘18→’19, IMF): (미국) 2.9 → 2.5 (중국) 6....
# 44   2019    미국               ▪ (기타) 글로벌 보호무역주의 확대 , 미국 금리인상 및 신흥국
# 45   2019   고용부  ▪ 정부 복지 확충에도 불구, 온라인화.자동화 등에 따른 임시. 일용직 고용부진, ...
# 46   2019   고용부  * 지원체계 구축 위한 관계기관 T/F(기재부·고용부·행안부·산업부・중기부) 구성(...
# 47   2019   고용부  ᄋ 고용부진.소비심리 약화 등에도 불구, 임금상승 등 소득여건 개선에 힘입어 견조한...
# 48   2019   고용부                                                고용부
# 49   2019   고용부                                                고용부
# 50   2019   고용부                                                고용부
# 51   2019   고용부                                                고용부
# 52   2019   고용부                                                고용부
# 53   2019   고용부                                                고용부
# 54   2019   고용부                                                고용부
# 55   2019   고용부                                            기재부 고용부
# 56   2019   고용부                                                고용부
# 57   2019   고용부                                                고용부
# 58   2019    남북  §4차 산업혁명 대비 §저출산・고령화 대응 §남북경협 준비 본격화 §중장기 비전과 ...
# 59   2019    남북  ◇ 4차 산업혁명, 저출산 고령화, 남북경협 등 미래 도전요인에 대비한 선제적 투자...
# 60   2019    남북                                    (3) 남북경협 준비 본격화
# 61   2019    남북  ➊ 비핵화 진전 등 여건 조성시 경협사업 추진을 위한 남북 협의 채널을 본격 가동하...
# 62   2019    남북  ➋ 북한의 국제금융기구(IMF, WB) 가입 지원 등 남북경협에 대한 국제사회의 지...
# 63   2019    남북  ➌ 여건 조성시, 남북간 합의된 경제협력 사업 중 실현가능한 사업부터 국제사회와 공...
# 64   2019    남북     ▪남북간 철도.도로 연결 및 현대화사업, 남북간 산림협력 및 한강하구 공동이용 추진
# 65   2019    남북                ▪ 남북 공동특구 구상 구체화를 위한 공동조사 및 연구 등 추진
# 66   2019    한국  ‣ 청년 희망사다리 강화방안 마련 ‣서민・자영업자 소득증대・부담경감 ‣ 한국형 실업...
# 67   2019    한국          2」 국내보증기관은 외국인이 창업한 국내기업 보증, 해외보증기관은 한국인이
# 68   2019    한국  ▪페스티벌 기간 중 세계 각지에서 K-pop 콘테스트를 개최하고, 국내에서 본선을 ...
# 69   2019    한국  ➌ 서울 등을 중심으로 시내 면세점을 추가 설치하는 등 외국인 관광객에 대한 편의를...
# 70   2019    한국                 ▪ 중국.일본 등 주요 한국 방문국가를 대상으로 현지스타 등을
# 71   2019    한국  ▪ 신용평가사와의 협의, 해외투자자에 대한 정보제공을 지속하고, 관계부처 합동 한국...
# 72   2019    한국  ➋ 고용보험에 가입하지 않은 근로빈곤층 등을 지원하기 위한 한국형 실업부조 도입기반 구축
# 73   2019    한국               ‣서민・영세자영업자 소득증대 및 부담 경감 ‣한국형 실업부조 도입
# 74   2019    한국                                      ➌ 한국형 실업부조 도입
# 75   2019    한국  ➌ 실업급여를 확대하는 한편, 상반기 중 공청회, 전문가 논의 등 거쳐 한국형 실업...
# 76   2019    한국       주1) ‘18년은 1~10월 * 출처 : 국토부, 감정원 * 출처 : 한국감정원
# 77   2019    서울                           ➃ 서울 창동 K-Pop 공연장(0.5조원)
# 78   2019    서울                  ▪서울 인근 신규 공공택지의 주거.업무기능 조기 활성화를 *
# 79   2019    서울  ➌ 서울 등을 중심으로 시내 면세점을 추가 설치하는 등 외국인 관광객에 대한 편의를...
# 80   2019    서울                     * ‘18.10월 기준 시내면세점 26개(서울 12개)
# 81   2019    서울  * Cooperative-Intelligent Transport System(현재 ...
# 82   2019    서울  * 반도체 특화클러스터(1.6조원), 글로벌 비즈니스 센터(3.7조원), 자동차 주...
# 83   2019    서울  ᄋ 주택 매매시장은 전국적으로 안정세, 8월 이후 단기급등했던 서울 주택가격도 9....
# 84   2019    서울                               * 서울 주간아파트가격 상승률(%):
# 85   2019    일본               포용적 성장론 확산, 미국, 일본 등 주요국도 관련 정책 시행 중
# 86   2019    일본  ➊ 세계경제는 완만한 성장세가 유지되나, 중국.미국.일본 등 우리경제와 밀접한 주요...
# 87   2019    일본                 ▪ 중국.일본 등 주요 한국 방문국가를 대상으로 현지스타 등을
# 88   2019    일본  ▪지역별로는 중국.일본.EU.아세안.미국 등 대부분 지역에 대해 수출이 증가하였으나...
# 89   2019    일본  * 지역별 수출(‘17.1~11→ 18.1~11, 전년비, %): (중국)17.2 ...
# 90   2019    일본  ▪ 일본은 소비세 인상(‘19.10월 예정)으로 성장세 둔화가 전망되나 2020 동...
# 91   2019    인도  ᄋ 우리 경제는 분배가 지속 악화되고 저성장이 고착화되는 가운데, 미래 도전요인도 ...
# 92   2019    인도                          ▪ 인도 단체관광객에 대한 단체비자 제도 도입
# 93   2019    인도         * 現 단체비자 허용 국가 : 베트남, 중국, 필리핀, 인도네시아, 캄보디아
# 94   2019    인도   * 美시애틀·인도 시범 설치‧운영(‘19년) → 초기 운영성과 평가 후 지역 확대 검토
# 95   2019    인도  * RCEP(역내포괄적 경제동반자협정) : Regional Comprehensive...
# 96   2019    인도  ▪ 한-러시아 서비스.투자 FTA 협상을 개시하고, 인도네시아, 말레이시아 등 아세...
# 97   2019    인도  ▪ 신흥국은 인도, 아세안 5국 중심 양호한 성장세가 전망되나 아르헨티나, 터키 등...
# 98   2019    인도                       인도(전년동기비) 7.7 브라질(전년동기비) 1.2
# 99   2019    인도                           무역분쟁에 따른 수요감소 등 하방요인도 존재
# 100  2019    인도                          ▪ 인도 단체관광객에 대한 단체비자 제도 도입
# 101  2019   아세안  ▪(신남방) 한-아세안 FTA 추가 자유화 및 RCEP 협상 가속화, 한-아세안 글...
# 102  2019   아세안  ▪ 한-러시아 서비스.투자 FTA 협상을 개시하고, 인도네시아, 말레이시아 등 아세...
# 103  2019   아세안  ▪지역별로는 중국.일본.EU.아세안.미국 등 대부분 지역에 대해 수출이 증가하였으나...
# 104  2019   아세안  * 지역별 수출(‘17.1~11→ 18.1~11, 전년비, %): (중국)17.2 ...
# 105  2019   아세안  ▪ 신흥국은 인도, 아세안 5국 중심 양호한 성장세가 전망되나 아르헨티나, 터키 등...
# 0    2018  한국은행                       * 자료 : 한국은행 * 자료 : 통계청, 한국은행
# 1    2018  한국은행                   * 자료 : 한국은행, 국금센터 * 자료 : 산업기술평가원
# 2    2018  한국은행                     * 자료 : 한국은행 * 자료 : 통계청, 장래인구추계
# 3    2018  한국은행                 * 출처 : 한국은행 * 출처 : 관세청, 선박제외 수출 기준
# 4    2018  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 5    2018  한국은행                       * 출처 : 한국은행 * 출처 : 한국은행, 통계청
# 6    2018  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 7    2018  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 8    2018  한국은행                            * 출처 : 한국은행 * 출처 : 한국은행
# 9    2018  한국은행                         * 출처: 관세청, 한국은행 * 출처: 무역협회
# 10   2018  한국은행      * 출처 : 한국은행 ** ‘17~’18은 정부전망 * 출처 : IMF, 한국은행
# 11   2018  한국은행  주1) 실질구매력 = 실질임금 × 취업자수 * 출처 : 한국감정원, 통계청 * 출처...
# 12   2018  한국은행                        * 출처 : 한국은행, 통계청 * 출처 : 통계청
# 13   2018  한국은행                      * 출처 : 과학기술정보통신부, 기획재정부, 한국은행
# 14   2018  한국은행                 * 출처 : 한국은행, 통계청 * 출처 : 소프트웨어정책연구소
# 15   2018  한국은행     주1) BSI지수가 높을수록 인력과잉 의미 * 출처 : 통계청 * 출처 : 한국은행
# 16   2018    한국                                              한국 세계
# 17   2018    한국                                            한국 기준금리
# 18   2018    한국                                     한국 시중금리(국고채3년)
# 19   2018    한국                                             한국(4위)
# 20   2018    한국        * 고령사회 진입 소요기간 : (한국) 17년 (일본) 24년 (미국) 72년
# 21   2018    한국                                                 한국
# 22   2018    한국                                              중국 한국
# 23   2018    한국  * 자료 : OECD, '16년 기준 * 자료 : OECD(‘14년), 한국은 ‘1...
# 24   2018    한국  * 자료 : IMF('17.10) * 자료 : OECD(‘14년), 한국은 ‘16년 기준
# 25   2018    한국                                         OECD 평균 한국
# 26   2018    한국                                          한국 OECD평균
# 27   2018    한국                                          선진국 일본 한국
# 28   2018    한국  ▪ 일자리 창출 우수기업의 EDCF 참여기회를 확대 하고 한국인 참여 개발사업 확대...
# 29   2018    한국  * 고용증가 기업에 대하여 수은의 타당성조사를 위한 입찰평가시 가점 부여, 수원국에...
# 30   2018    한국  ᄋ 대기업→中企→근로자 로 이어지는 한국형 협력이익공유 모델을 확산하고, 민간 자율...
# 31   2018    한국              - 한국해양진흥공사 설립(‘18년) 및 이를 통한 선박 확충, 화물
# 32   2018    한국  * (원양 ‘컨’) 선복량·해외터미널 확충, (연근해 ‘컨’) 한국해운협의체 중심의...
# 33   2018    한국  ᄋ 평창 동계올림픽(2.9~2.25)과 이와 연계한 ‘한국 방문의 해’를 계기로 국...
# 34   2018    한국                 ▪ 평창동계올림픽과 한국 및 지역문화가 반영된 축제 공연 예술
# 35   2018    한국  ᄋ 그간 뉴욕.런던 중심의 한국경제 설명회(IR)를 홍콩.싱가폴. 상하이 등으로 확...
# 36   2018    한국       주1) ‘17년은 1~11월 * 출처 : 국토부, 감정원 * 출처 : 한국감정원
# 37   2018    한국                                      세계교역량 한국 수출물량
# 38   2018    한국                                한국경제설명회 확대 개최 (상시)
# 39   2018    중국                                              중국 한국
# 40   2018    중국  ▪ 웰니스(wellness) 등 관광분야 융복합 수요와 연계하여 중국. 동남아 등 ...
# 41   2018    중국  * (’17) 산업・중기부(1,786억원) → (’18) 산업・중기・농림・해수・특허...
# 42   2018    중국                  ▪ 중국 남서부 지역 진출을 희망하는 유망 스타트업의 한·중
# 43   2018    중국  * 한・중 혁신창업 협력 MOU(’15.10월)에 따라 중국 정부가 ’16.3월 쓰...
# 44   2018    중국  *중국인대상요건충족시15일무비자 **올림픽전후정상출입국자대상 *** ‘코리아투어카드...
# 45   2018    중국  ▪ 지역별로는 아세안·EU·중국·일본·미국 등 주요 지역에 대한 수출이 증가하였으나...
# 46   2018    중국  ᄋ 중국은 세계경제 개선에 따른 수출 회복세가 지속되는 가운데 소득.심리 등 소비여...
# 47   2018    중국  * 중국 1인당 가처분소득(전년누계비, %) : (‘16)6.3 (‘17.1/4)7...
# 48   2018    중국                                                 중국
# 49   2018    중국  ᄋ 중국은 주택시장 안정화 정책으로 인한 부동산 둔화 가능성, 과잉설비 산업 구조조...
# 50   2018    중국  * 세계 곡물 재고율(%, 기말재고/기간소비, 美 농무부) : (’16) 25.7 ...
# 51   2018    중국      * 세계 최대 알루미늄 생산국인 중국 환경규제로 알루미늄 제련소 가동률 축소 예상
# 52   2018    중국  향후 美 금리, 달러화 강세 여부, 중국 경기 상황 등에 따라 신흥국으로의 자금흐름...
# 53   2018    중국                    중국인 방한 관광객 추이 최저임금 인상과 소비증가액 추정
# 54   2018    중국                                     중국인방한관광객 면세점매출
# 55   2018    중국  ▪ 통상현안 완화에 따른 중국인 관광객 증가, 휴대폰 해외생산 확대 등으로 여행.지...
# 56   2018    중국  * 중국인 관광객 증가율(%) : (’17.2/4)△65.7 (3/4)△62.7 (...
# 57   2018    일본        * 고령사회 진입 소요기간 : (한국) 17년 (일본) 24년 (미국) 72년
# 58   2018    일본                                              미국 일본
# 59   2018    일본                                          선진국 일본 한국
# 60   2018    일본                               (17년 소요, 일본은 24년 소요)
# 61   2018    일본                   통해 일본 아세안 지역 1만명(‘18~’20년) 취업 지원
# 62   2018    일본  * 예) 우리 대학 3년 + 일본 대학 1년 → 일본 취업 ** 국내 대학‧일본 대...
# 63   2018    일본  * 사업자 소재국 기관에서 사건을 처리하고 소비자 소재국 기관에 통보 (미국, 일본...
# 64   2018    일본  ▪ 지역별로는 아세안·EU·중국·일본·미국 등 주요 지역에 대한 수출이 증가하였으나...
# 65   2018    일본  ᄋ 일본은 세계교역 회복, 도쿄 올림픽 대비 인프라 확충 등에 힘입어 수출.투자 중...
# 66   2018    평창  기술개발 R&D 확대(고해상도 카메라·레이더 등 핵심부품 관련), 실증 인프라 확충...
# 67   2018    평창  - (자율차) 9대 핵심부품을 집중 개발하고, 판교.평창올림픽 시범운행(2월) 등 ...
# 68   2018    평창  ᄋ 평창 동계올림픽(2.9~2.25)과 이와 연계한 ‘한국 방문의 해’를 계기로 국...
# 69   2018    평창         ▪ ‘18년 겨울 여행주간을 “평창 여행의 달(2.9~3.18)”로 확대하고
# 70   2018    평창                          * 평창및강원도특별관광및각종체험프로그램 등운영
# 71   2018    평창                 * 평창・정선 지역 관광체험단 운영, 레일시티투어 시범운영 등
# 72   2018    평창                 ▪ 평창동계올림픽과 한국 및 지역문화가 반영된 축제 공연 예술
# 73   2018    평창               발급 확대**, 평창올림픽 전용 관광패스 혜택 확대*** 등 추진
# 74   2018    평창  *중국인대상요건충족시15일무비자 **올림픽전후정상출입국자대상 *** ‘코리아투어카드...
# 75   2018    평창  ▪ 상반기는 평창 올림픽, 통상현안 완화 등으로 회복 흐름이 이어지겠으나, 시중 금...
# 76   2018    평창  ▪ 다만, 비주거용 건물의 착공면적 감소, 평창올림픽 관련 공사 마무리에 따른 투자...
# 77   2018    평창  ‘겨울여행 주간’을 ‘평창 여행의 달’로 확대 (1분기) 청탁금지법 시행령 개정...
# 78   2018   고용부  ᄋ 다만, 특정부문 중심 성장으로 부문간 격차가 지속되고 있고 분배악화.고용부진 등...
# 79   2018   고용부                         * 자료 : 통계청 * 자료 : 고용부, 통계청
# 80   2018   고용부                 ᄋ 온라인 취업 활성화를 위해 워크넷(고용부) 기업관련 데이터
# 81   2018   고용부                                            고용부 교육부
# 82   2018   고용부                                            중기부 고용부
# 83   2018   고용부                                        고용부 복지부 중기부
# 84   2018   고용부                 노사상생형 일자리 창출시 컨설팅 지원 우대 (상반기) 고용부
# 85   2018   고용부                                            기재부 고용부
# 86   2018   고용부                                    금융위 기재부 고용부 복지부
# 87   2018   고용부                                기재부 국토부 고용부 금융위 인사처
# 88   2018   고용부                                            고용부 기재부
# 89   2018    미국                                            미국 기준금리
# 90   2018    미국        * 고령사회 진입 소요기간 : (한국) 17년 (일본) 24년 (미국) 72년
# 91   2018    미국                                              미국 일본
# 92   2018    미국  * 사업자 소재국 기관에서 사건을 처리하고 소비자 소재국 기관에 통보 (미국, 일본...
# 93   2018    미국  ▪ 지역별로는 아세안·EU·중국·일본·미국 등 주요 지역에 대한 수출이 증가하였으나...
# 94   2018    미국  ᄋ 미국은 고용여건 호조 및 세제 개편 등에 힘입어 민간소비. 투자 등 내수 중심의...
# 95   2018    미국                                                 미국
# 96   2018    미국  ▪ (지역별) 선진국.신흥국 회복으로 EU.미국.아세안 등에 대한 수출 증가 예상,...
# 97   2018   공정위  ▪ 대기업이 1차와 2차 이하 협력사간 공정거래협약 체결을 독려할 수 있도록 협약이...
# 98   2018   공정위  ▪ (행정) 과징금 부과기준율 상한 2배 상향, 행정수요가 많은 가맹 분야에서 공정...
# 99   2018   공정위  * 피해자가 공정위를 거치지 않고 법원에 직접 불공정행위 중단 소송을 제기하는 제도...
# 100  2018   공정위  소액체당금 요건 간소화 관련법 개정안 마련 (1분기) 약속어음 단계적 폐지 위한...
# 101  2018   공정위                                        공정위 기재부 법무부
# 102  2018   공정위                                        공정위 복지부 기재부
# 103  2018   아세안                   통해 일본 아세안 지역 1만명(‘18~’20년) 취업 지원
# 104  2018   아세안                      확대·개편하여 아세안 등 신흥시장 진출기업 지원 강화
# 105  2018   아세안  ▪ 지역별로는 아세안·EU·중국·일본·미국 등 주요 지역에 대한 수출이 증가하였으나...
# 106  2018   아세안  * 지역별 수출(‘16→17.1~11, 전년비, %) : (아세안)△0.4→27.6...
# 107  2018   아세안  ▪ (지역별) 선진국.신흥국 회복으로 EU.미국.아세안 등에 대한 수출 증가 예상,...
# 108  2018    서울         서울 1인가구)와 교육급여(9.5→16.2만원, 70%, 중고생) 대폭 인상
# 109  2018    서울   * 수은・산은・무보・서울보증・건설공제조합 / ** 합의기관만 보증발급 참여 - 35 -
# 110  2018    서울  * 일자리, 주거, 출산·육아, 생활·여가 등에 대해 청년들이 정책제언을 하는 권역...
# 111  2018    서울  ᄋ 주택 매매시장은 전년대비 가격상승세가 소폭 확대되었으나, 8.2대책 이후 서울 ...
# 112  2018    서울  * 서울 아파트가격(전월비, %) : (‘17.6) 1.0 (7) 0.5 (8) 0...

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # 고유명사 찾기

# %%
counters_2019['NNP'].most_common(14)
# Out:
# [('한국은행', 21),
#  ('중국', 15),
#  ('미국', 14),
#  ('물류', 14),
#  ('최저임금', 11),
#  ('고용부', 11),
#  ('바이오', 10),
#  ('저출산', 9),
#  ('남북', 9),
#  ('한국', 9),
#  ('서울', 8),
#  ('일본', 6),
#  ('크루즈', 6),
#  ('인도', 6)]

# %%
tag = 'NNP'
x = 30

top_10_2019 = tuple(zip(*counters_2019[tag].most_common(x)))[0]; top_10_2019

top_10_2018 = tuple(zip(*counters_2018[tag].most_common(x)))[0]; top_10_2018

pprint(top_10_2019)

'''
2019
['한국은행', '중국', '미국', '고용부', '남북', '한국', '서울', '일본', '인도', '아세안',]
'바이오', '크루즈', 

2018
['한국은행', '한국', '중국', '일본', '평창', '고용부', '미국', '공정위', '아세안', '서울',]
'''

print()
pprint(top_10_2018)
# Out:
# ('한국은행',
#  '중국',
#  '미국',
#  '물류',
#  '최저임금',
#  '고용부',
#  '바이오',
#  '저출산',
#  '남북',
#  '한국',
#  '서울',
#  '일본',
#  '크루즈',
#  '인도',
#  '아세안',
#  '조선',
#  '기저',
#  '균형발전',
#  '정책금융',
#  '공유',
#  '거시경제',
#  '미세먼지',
#  '강화',
#  '강원',
#  '행안',
#  '고위험',
#  '임상시험',
#  '드론',
#  '스마트',
#  '채무조정')
#
# ('한국은행',
#  '한국',
#  '중국',
#  '저출산',
#  '거시경제',
#  '일본',
#  '평창',
#  '고용부',
#  '스마트',
#  '균형발전',
#  '로드맵',
#  '올림픽',
#  '미국',
#  '최저임금',
#  '팜',
#  '연기금',
#  '조선',
#  '공정위',
#  '채무조정',
#  '매칭',
#  '아세안',
#  '드론',
#  '서울',
#  '물류',
#  '기업지배구조',
#  '복지부',
#  '공정',
#  '샌드박스',
#  '산은',
#  '리츠')

# %% [markdown]
# # 2019년에 새로 등장한 단어: (among top 40)

# %% [markdown]
# ## 공공, 구조, 대상, 둔화, 서비스, 조성

# %%
top40_set_2019 = set(list(zip(*counters_2019['NNG'].most_common(40)))[0])
top40_set_2018 = set(list(zip(*counters_2018['NNG'].most_common(40)))[0])

top40_set_2019 - top40_set_2018
# Out:
# {'공공', '구조', '대상', '둔화', '서비스', '조성'}

# %% [markdown]
# # 2018년에만 있었던 단어: (among top 40)

# %% [markdown]
# ## 구축, 상승, 중심, 청년, 출처, 평가

# %%
top40_set_2018 - top40_set_2019
# Out:
# {'구축', '상승', '중심', '청년', '출처', '평가'}

# %%
x = 10
top_x_set_2019 = set(list(zip(*counters_2019['NNG'].most_common(x)))[0])
top_x_set_2018 = set(list(zip(*counters_2018['NNG'].most_common(x)))[0])

print(top_x_set_2019 & top_x_set_2018)
print(top_x_set_2019 - top_x_set_2018)
print(top_x_set_2018 - top_x_set_2019)
# Out:
# {'강화', '투자', '경제', '지원', '기업', '추진', '확대'}
# {'사업', '산업', '전망'}
# {'혁신', '금융', '개선'}

# %%
top_x_set_2019
# Out:
# {'강화', '경제', '기업', '사업', '산업', '전망', '지원', '추진', '투자', '확대'}
